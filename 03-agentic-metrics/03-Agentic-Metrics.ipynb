# %% [markdown]
# # Agents Evaluation Framework
#
# ## Overview
# This notebook demonstrates comprehensive techniques for evaluating Agent Performance, Tool Execution and Reliability
#
# ### Agents Evaluation Dimensions:
# - **Agent Performance**: Measuring accuracy using ground truth datasets
# - **Tool Execution**: Analyzing tool selection and execution success rates
# - **Resource Efficiency**: Token usage, latency, and cycle duration analysis
# - **Agent Reliability**: Consistency across multiple test scenarios

# %% [markdown]
# ## 1. Dependencies Installation

# %%
# !pip install strands-agents strands-agents-tools --upgrade
# !pip install ddgs
# !pip install bedrock_agentcore
# Out:
# Looking in indexes: https://pypi.org/simple, https://plugin.us-east-1.prod.workshops.aws
# Requirement already satisfied: strands-agents in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (1.35.0)
# Requirement already satisfied: strands-agents-tools in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (0.5.0)
# Requirement already satisfied: boto3<2.0.0,>=1.26.0 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from strands-agents) (1.42.90)
# Requirement already satisfied: botocore<2.0.0,>=1.29.0 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from strands-agents) (1.42.90)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from strands-agents) (0.18.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from strands-agents) (4.26.0)
# Requirement already satisfied: mcp<2.0.0,>=1.23.0 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from strands-agents) (1.27.0)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.30.0 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from strands-agents) (1.41.0)
# Requirement already satisfied: opentelemetry-instrumentation-threading<1.00b0,>=0.51b0 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from strands-agents) (0.62b0)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.30.0 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from strands-agents) (1.41.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.4.0 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from strands-agents) (2.13.2)
# Requirement already satisfied: pyyaml<7.0.0,>=6.0.0 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from strands-agents) (6.0.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.13.2 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from strands-agents) (4.15.0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from strands-agents) (6.0.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from boto3<2.0.0,>=1.26.0->strands-agents) (1.1.0)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from boto3<2.0.0,>=1.26.0->strands-agents) (0.16.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from botocore<2.0.0,>=1.29.0->strands-agents) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from botocore<2.0.0,>=1.29.0->strands-agents) (2.6.3)
# Requirement already satisfied: attrs>=22.2.0 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents) (0.30.0)
# Requirement already satisfied: anyio>=4.5 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents) (4.13.0)
# Requirement already satisfied: httpx-sse>=0.4 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents) (0.4.3)
# Requirement already satisfied: httpx>=0.27.1 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents) (0.28.1)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents) (2.13.1)
# Requirement already satisfied: pyjwt>=2.10.1 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.23.0->strands-agents) (2.12.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents) (0.0.26)
# Requirement already satisfied: sse-starlette>=1.6.1 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents) (3.3.4)
# Requirement already satisfied: starlette>=0.27 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents) (1.0.0)
# Requirement already satisfied: typing-inspection>=0.4.1 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents) (0.4.2)
# Requirement already satisfied: uvicorn>=0.31.1 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents) (0.44.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from opentelemetry-api<2.0.0,>=1.30.0->strands-agents) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<2.0.0,>=1.30.0->strands-agents) (3.23.1)
# Requirement already satisfied: opentelemetry-instrumentation==0.62b0 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents) (0.62b0)
# Requirement already satisfied: wrapt<3.0.0,>=1.0.0 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents) (2.1.2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.62b0 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from opentelemetry-instrumentation==0.62b0->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents) (0.62b0)
# Requirement already satisfied: packaging>=18.0 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from opentelemetry-instrumentation==0.62b0->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents) (26.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.2 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents) (2.46.2)
# Requirement already satisfied: six>=1.5 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<2.0.0,>=1.29.0->strands-agents) (1.17.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.0 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from strands-agents-tools) (3.13.5)
# Requirement already satisfied: aws-requests-auth<0.5.0,>=0.4.3 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from strands-agents-tools) (0.4.3)
# Requirement already satisfied: dill<0.5.0,>=0.4.0 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from strands-agents-tools) (0.4.1)
# Requirement already satisfied: markdownify<2.0.0,>=1.0.0 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from strands-agents-tools) (1.2.2)
# Requirement already satisfied: pillow<13.0.0,>=12.1.1 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from strands-agents-tools) (12.2.0)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.51 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from strands-agents-tools) (3.0.52)
# Requirement already satisfied: requests<3.0.0,>=2.28.0 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from strands-agents-tools) (2.33.1)
# Requirement already satisfied: rich<15.0.0,>=14.0.0 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from strands-agents-tools) (14.3.4)
# Requirement already satisfied: slack-bolt<2.0.0,>=1.23.0 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from strands-agents-tools) (1.28.0)
# Requirement already satisfied: sympy<2.0.0,>=1.12.0 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from strands-agents-tools) (1.14.0)
# Requirement already satisfied: tenacity<10.0.0,>=9.1.2 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from strands-agents-tools) (9.1.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools) (1.23.0)
# Requirement already satisfied: beautifulsoup4<5,>=4.9 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from markdownify<2.0.0,>=1.0.0->strands-agents-tools) (4.14.3)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from beautifulsoup4<5,>=4.9->markdownify<2.0.0,>=1.0.0->strands-agents-tools) (2.8.3)
# Requirement already satisfied: wcwidth in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from prompt-toolkit<4.0.0,>=3.0.51->strands-agents-tools) (0.6.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools) (3.11)
# Requirement already satisfied: certifi>=2023.5.7 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools) (2026.2.25)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools) (2.20.0)
# Requirement already satisfied: slack_sdk<4,>=3.38.0 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from slack-bolt<2.0.0,>=1.23.0->strands-agents-tools) (3.41.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from sympy<2.0.0,>=1.12.0->strands-agents-tools) (1.3.0)
# Requirement already satisfied: httpcore==1.* in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from httpx>=0.27.1->mcp<2.0.0,>=1.23.0->strands-agents) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from httpcore==1.*->httpx>=0.27.1->mcp<2.0.0,>=1.23.0->strands-agents) (0.16.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=14.0.0->strands-agents-tools) (0.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from pydantic-settings>=2.5.2->mcp<2.0.0,>=1.23.0->strands-agents) (1.2.2)
# Requirement already satisfied: cryptography>=3.4.0 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.23.0->strands-agents) (46.0.7)
# Requirement already satisfied: cffi>=2.0.0 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.23.0->strands-agents) (2.0.0)
# Requirement already satisfied: pycparser in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.23.0->strands-agents) (3.0)
# Requirement already satisfied: click>=7.0 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from uvicorn>=0.31.1->mcp<2.0.0,>=1.23.0->strands-agents) (8.3.2)
# Looking in indexes: https://pypi.org/simple, https://plugin.us-east-1.prod.workshops.aws
# Requirement already satisfied: ddgs in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (9.14.0)
# Requirement already satisfied: click>=8.1.8 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from ddgs) (8.3.2)
# Requirement already satisfied: primp>=1.2.0 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from ddgs) (1.2.2)
# Requirement already satisfied: lxml>=4.9.4 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from ddgs) (6.0.4)
# Looking in indexes: https://pypi.org/simple, https://plugin.us-east-1.prod.workshops.aws
# Requirement already satisfied: bedrock_agentcore in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (1.6.3)
# Requirement already satisfied: boto3>=1.42.86 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from bedrock_agentcore) (1.42.90)
# Requirement already satisfied: botocore>=1.42.86 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from bedrock_agentcore) (1.42.90)
# Requirement already satisfied: pydantic<2.41.3,>=2.0.0 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from bedrock_agentcore) (2.13.2)
# Requirement already satisfied: starlette>=0.46.2 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from bedrock_agentcore) (1.0.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.13.2 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from bedrock_agentcore) (4.15.0)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from bedrock_agentcore) (2.6.3)
# Requirement already satisfied: uvicorn>=0.34.2 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from bedrock_agentcore) (0.44.0)
# Requirement already satisfied: websockets>=12.0 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from bedrock_agentcore) (16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from pydantic<2.41.3,>=2.0.0->bedrock_agentcore) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.2 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from pydantic<2.41.3,>=2.0.0->bedrock_agentcore) (2.46.2)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from pydantic<2.41.3,>=2.0.0->bedrock_agentcore) (0.4.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from boto3>=1.42.86->bedrock_agentcore) (1.1.0)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from boto3>=1.42.86->bedrock_agentcore) (0.16.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from botocore>=1.42.86->bedrock_agentcore) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from python-dateutil<3.0.0,>=2.1->botocore>=1.42.86->bedrock_agentcore) (1.17.0)
# Requirement already satisfied: anyio<5,>=3.6.2 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from starlette>=0.46.2->bedrock_agentcore) (4.13.0)
# Requirement already satisfied: idna>=2.8 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from anyio<5,>=3.6.2->starlette>=0.46.2->bedrock_agentcore) (3.11)
# Requirement already satisfied: click>=7.0 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from uvicorn>=0.34.2->bedrock_agentcore) (8.3.2)
# Requirement already satisfied: h11>=0.8 in /Users/afiakhan/aws-samples/github/sample-gen-ai-evaluations-workshop/.venv/lib/python3.14/site-packages (from uvicorn>=0.34.2->bedrock_agentcore) (0.16.0)

# %% [markdown]
# ## 2. Imports

# %%
from strands import Agent, tool 
from strands.models import BedrockModel 
from bs4 import BeautifulSoup 
import requests 
import pandas as pd, re

# %% [markdown]
# ## 3. Ground Truth Dataset Loading

# %%
# Read the CSV file
#this contains the city, state, population, and land area in square miles in 2024.
gold_standard_city_pop = pd.read_csv('city_pop.csv')
# Clean the dataset once when loading, wikipedia has commas in the numbers.
gold_standard_city_pop['population'] = gold_standard_city_pop['population'].astype(str).str.replace(',', '').astype(float)
gold_standard_city_pop['land_area_mi2'] = gold_standard_city_pop['land_area_mi2'].astype(str).str.replace(',', '').astype(float)

# Show the first 3 rows, as a reference
print(gold_standard_city_pop.head(3))  # First 3 rows
# Out:
#           city state  population  land_area_mi2
# 0  New York[c]    NY   8478072.0          300.5
# 1  Los Angeles    CA   3878704.0          469.5
# 2      Chicago    IL   2721308.0          227.7

# %% [markdown]
# ## 4. Core Evaluation Function
#
# This function performs comprehensive evaluation of agent responses by extracting structured data from XML tags and calculating accuracy metrics. It parses population and area estimates from the agent's response using regex patterns,then compares these against ground truth data from the dataset to compute percent error rates.
#
# The function also captures key performance metrics including token usage, execution time, and tool call frequency from the agent's built-in observability system. This dual approach enables both accuracy assessment and resource efficiency analysis in a single evaluation pass.

# %%
def evaluate_city_guess(city, state, chatbot_response, dataset):
    """
    Evaluate population and area guesses against the gold standard dataset.
    
    Parameters:
    - city: str, city name
    - state: str, state abbreviation (e.g., 'NY', 'CA')
    - chatbot_response: Strands AgentResult object to be evaluated
    - dataset: pandas DataFrame, the gold standard dataset
    
    Returns:
    - dict with percent errors for population and area, and total tokens, execution time, and tool calls.
    
    Raises:
    - ValueError if city/state combination not found
    """
    
    # Clean the city name for matching
    city_clean = city.strip()

    
    #use regex to grab the final answer as numbers
    final_msg = chatbot_response.message['content'][0]['text']
    try:
        guessed_pop, guessed_area = int(re.search(r'<pop>(.*?)</pop>', final_msg).group(1)), float(re.search(r'<area>(.*?)</area>', final_msg).group(1))
    except:
        raise ValueError(f"XML tags not found in reply")

    
    #extract agent loop metrics
    total_tokens = chatbot_response.metrics.accumulated_usage['totalTokens']
    total_time = sum(chatbot_response.metrics.cycle_durations)
    
    tool_calls = 0
    for t in chatbot_response.metrics.tool_metrics.keys():
        tool_calls+= chatbot_response.metrics.tool_metrics[t].call_count

    
    # Find the city in the dataset
    # Use case-insensitive matching and handle potential annotations
    mask = (dataset['city'].str.replace(r'\[.*\]', '', regex=True).str.strip().str.lower() == city_clean.lower()) & \
           (dataset['state'].str.upper() == state.upper())
    
    matching_rows = dataset[mask]
    
    if len(matching_rows) == 0:
        raise ValueError(f"City '{city}' in state '{state}' not found in dataset")
    
    if len(matching_rows) > 1:
        print(f"Warning: Multiple matches found for {city}, {state}. Using first match.")
    
    # Get the actual values
    actual_pop = matching_rows.iloc[0]['population']
    actual_area = matching_rows.iloc[0]['land_area_mi2']
    
    # Calculate percent error: |actual - guess| / actual * 100
    pop_error = abs(actual_pop - guessed_pop) / actual_pop * 100
    area_error = abs(actual_area - guessed_area) / actual_area * 100
    
    return {
        'city': matching_rows.iloc[0]['city'],
        'state': matching_rows.iloc[0]['state'],
        'actual_population': actual_pop,
        'guessed_population': guessed_pop,
        'population_error_percent': round(pop_error, 2),
        'actual_area': actual_area,
        'guessed_area': guessed_area,
        'area_error_percent': round(area_error, 2),
        'total_tokens': total_tokens,
        'total_time': total_time,
        'tool_calls': tool_calls
    }

# %% [markdown]
# ## 5. Agent Tools
#
# These two tools enable web-based information retrieval for the agent.
#
# * The web_search tool queries DDGS (a metasearch library) to find relevant web pages, returning up to 5 results with titles, URLs, and snippets.
# * The get_page tool extracts raw text content from specific URLs, allowing the agent to dive deeper into search results.
#
# Together, they provide a complete web research capability that enables agents to access current information beyond their training data when evaluating tasks like population queries.

# %%
@tool
def web_search(topic: str) -> str:
    """Search the web for a given topic using DDGS metasearch."""
    import subprocess, json, sys
    try:
        result = subprocess.run(
            [sys.executable, '-c',
             'import json; from ddgs import DDGS; '
             f'r=DDGS(timeout=4).text({json.dumps(topic)}, max_results=3, backend="html"); '
             'print(json.dumps(r))'],
            capture_output=True, text=True, timeout=10
        )
        if result.returncode != 0:
            return f"Search error: {result.stderr.strip()}"
        results = json.loads(result.stdout)
        if not results:
            return "No search results found"
        result_string = ""
        for i, r in enumerate(results):
            result_string += f"Result {i+1}: {r.get('title', 'No title')}\nURL: {r.get('href', 'No URL')}\nSnippet: {r.get('body', 'No description')}\n\n"
        return result_string
    except subprocess.TimeoutExpired:
        return "Search timed out after 10 seconds"
    except Exception as e:
        return f"Search error: {str(e)}"
    
@tool      
def get_page(url: str) -> str:
    """this function takes a URL and returns the raw text from that page.
    it can be used to get more info based on a Google search result listing."""
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        bs = BeautifulSoup(response.text,'html.parser')
        return bs.text
    except Exception as e:
        return f"Error fetching page: {str(e)}"

# %% [markdown]
# ## 6. AWS Bedrock Configuration
#
# These configurations optimize Bedrock API calls for different evaluation scenarios. The quick_config prioritizes speed with aggressive timeouts (5s connect, 20s read) and no retries, ideal for rapid evaluation runs where fast response times are critical. The longer_config provides more tolerance (10s connect, 60s read, 1 retry) for complex queries that may require additional processing time.
#
# This dual approach allows the evaluation framework to balance speed and reliability based on the specific testing requirements.

# %%
from botocore.config import Config

#A custom config for Bedrock to only allow short connections - for our demo we expect all calls to be fast.
#here we turn off retries, and we time out after 20 seconds.
quick_config = Config(
    connect_timeout=5,
    read_timeout=20,
    retries={"max_attempts": 0}
)

longer_config = Config(
    connect_timeout=10,
    read_timeout=60,
    retries={"max_attempts": 1}
)

# %% [markdown]
# ## 7. Single Agent Baseline Test
#
# This establishes a baseline evaluation by creating an agent with Nova Micro (optimized for speed and cost) and testing it against a specific query. The agent is equipped with web search capabilities and configured with aggressive timeouts for rapid evaluation.
#
# The test demonstrates the complete evaluation pipeline: the agent searches for New York population and area data, formats the response with XML tags for automated parsing, then the evaluation function measures accuracy against ground truth data while capturing performance metrics. This baseline provides a reference point for comparing different models, configurations, and evaluation scenarios.

# %% [markdown]
# ### Verbose Callback Handler
#
# Before creating the agent, we define a custom callback handler to display tool calls with their parameters. This helps us understand what the agent is doing during execution.

# %%
import json

# Custom callback handler to display tool calls with their parameters.
# 
# Strands agents stream output via callbacks. The callback receives kwargs including:
# - 'data': streaming text chunks from the model's response
# - 'current_tool_use': info about a tool being called (name, toolUseId, input)
#
# The challenge: tool input arrives as a streaming JSON string, so the callback fires
# multiple times as each character arrives. We detect completion by attempting to parse
# the JSON - if it parses successfully, the input is complete.
#
# We track toolUseId (unique per invocation) in a set to avoid duplicate prints.
# This allows the same tool to be called multiple times - each gets a unique ID.

seen_complete_tools = set()

def verbose_callback(**kwargs):
    """Callback handler that displays streaming text and tool calls with parameters."""
    # Stream text output as it arrives
    if 'data' in kwargs:
        print(kwargs['data'], end='', flush=True)
    
    # Display tool calls when their input is complete
    if 'current_tool_use' in kwargs:
        tool_use = kwargs['current_tool_use']
        tool_id = tool_use.get('toolUseId', 'no-id')
        tool_name = tool_use.get('name', 'no-name')
        tool_input = tool_use.get('input', '')
        
        # Skip if we've already printed this tool call
        if tool_id in seen_complete_tools:
            return
            
        # Try to parse the input as JSON - if successful, it's complete
        if isinstance(tool_input, str) and tool_input:
            try:
                parsed_input = json.loads(tool_input)
                seen_complete_tools.add(tool_id)
                print(f"\n\nTool Call: {tool_name} {json.dumps(parsed_input, indent=2)}")
                print()
            except json.JSONDecodeError:
                pass  # Input is still streaming, not yet valid JSON

# %%
#Create the chatbot.  We'll use Nova Micro to optimize for latency, cost, and capacity
chatbot_model_name = "us.amazon.nova-micro-v1:0"
#add custom timeout for the model, to keep the tool from hanging or retrying too much.
chatbot_model = BedrockModel(
    model_id=chatbot_model_name,
    boto_client_config=quick_config    
)
# Reset the tool tracking set for a fresh run
seen_complete_tools.clear()

chatbot = Agent(tools=[web_search,get_page], model=chatbot_model, callback_handler=verbose_callback)
#Call the chat bot with a simple request.
prompt = """How many people live in New York, and what's the area of the city in square miles?
After you respond, also include your answer in 'pop' and 'area' XML tags, for programatic processing.
The values in the XML tags should only be numbers, no words or commas."""
chatbot_response = chatbot(prompt)
# Out:
# <thinking> To answer the user's question about the population and area of New York, I will first need to search for this information using the web_search tool. I will then extract the relevant details and format the response as requested.</thinking>
#
#
#
# Tool Call: web_search {
#   "topic": "current population of New York City"
# }
#
#
#
# Tool Call: web_search {
#   "topic": "area of New York City in square miles"
# }
#
# <thinking> Based on the results from the web_search tool, I will extract the current population and area of New York City from the most reliable sources, and format the response as requested.</thinking>
#
# The population of New York City is approximately 8,584,629, and the area of the city is 473.3 square miles.
#
# Here is the response in the requested format:
#
# <pop>8584629</pop>
# <area>473.3</area>

# %%
result = evaluate_city_guess("New York", "NY", chatbot_response, gold_standard_city_pop)
print(f"Population error: {result['population_error_percent']}%")
print(f"Area error: {result['area_error_percent']}%")
print(f"Total Tokens: {result['total_tokens']} tokens")
print(f"Total Time: {result['total_time']:.2f} seconds")
print(f"Tool Calls: {result['tool_calls']}")
# Out:
# Population error: 1.26%
# Area error: 57.5%
# Total Tokens: 1967 tokens
# Total Time: 4.84 seconds
# Tool Calls: 2

# %% [markdown]
# ## 8. Single Model Evaluation Tool
#
# This function standardizes model evaluation by encapsulating the complete testing workflow into a reusable tool. It creates an agent with any specified Bedrock model, executes a consistent population query, and returns formatted performance metrics as a string.
#
# The function suppresses verbose output during execution and provides a clean summary of accuracy and efficiency metrics. This modular approach enables systematic comparison across different models using identical test conditions and evaluation criteria.

# %%
@tool
def eval_model(model_name: str) -> str:
    """Start an evaluator for a particular model.
    model_name is the model endpoint to be evaluated.
    Retruns a string containing information about this model.
    """
    #add custom timeout for the model, to keep the tool from hanging or retrying too much.
    chatbot_model = BedrockModel(
        model_id=model_name,
        boto_client_config=quick_config    
    )
    
    chatbot = Agent(tools=[web_search,get_page], model=chatbot_model, callback_handler=None)# callback_handler=None to suppress sub agent print outs
    #Call the chat bot with a simple request.
    prompt = """How many people live in Phoenix, AZ, and what's the area of the city in square miles?
    After you respond, also include your answer in 'pop' and 'area' XML tags, for programatic processing.
    The values in the XML tags should only be numbers, no words or commas."""
    chatbot_response = chatbot(prompt)
    result = evaluate_city_guess("Phoenix", "AZ", chatbot_response, gold_standard_city_pop)
    result_string = ""
    result_string = result_string + f"Population error: {result['population_error_percent']}%" + '\n'
    result_string = result_string + f"Area error: {result['area_error_percent']}%" + '\n'
    result_string = result_string + f"Total Tokens: {result['total_tokens']} tokens" + '\n'
    result_string = result_string + f"Total Time: {result['total_time']:.2f} seconds" + '\n'
    result_string = result_string + f"Tool Calls: {result['tool_calls']}"
    print (result_string)
    return result_string

# %% [markdown]
# ## 9. Multi-Model Comparison
#
# This demonstrates automated multi-model comparison using an agent equipped with the evaluation tool. The evaluator agent systematically tests five different models (Nova Micro, Lite, Pro, and Claude Haiku, Sonnet) using identical prompts and conditions.
#
# It handles failures with automatic retry logic and compiles results into a comparative table
# showing accuracy metrics, resource usage, and reliability statistics. This meta-evaluation approach showcases how agents can orchestrate complex evaluation workflows, providing comprehensive model performance analysis across the AWS Bedrock model family.

# %%
evaluator_prompt = """
Use the eval_model tool to evaluate these models:
Nova Micro: "us.amazon.nova-micro-v1:0",
Nova 2 Lite: "us.amazon.nova-2-lite-v1:0",
Nova Pro: "us.amazon.nova-pro-v1:0",
Claude Haiku 4.5: "us.anthropic.claude-haiku-4-5-20251001-v1:0",
Claude Sonnet 4.6: "us.anthropic.claude-sonnet-4-6"
Provide a table comparason on the results, and include columns for all evaluation data points, including number of tool calls, and the number of times the model failed to evaluate and had to be retried.
Do not include the endpoint names in the table, only the model names, to save space.
If a model fails to evaluate, you should retry it up to 3 times.
"""

# %%
evaluator = Agent(tools=[eval_model], model=chatbot_model)
evaluator_response = evaluator(evaluator_prompt)
# Out:
# <thinking> I need to evaluate the specified models using the `eval_model` tool. Since the tool can only be called once at a time and each model requires a separate call, I will need to make multiple sequential calls to the tool. After each call, I will check the results and if any model fails to evaluate, I will retry it up to 3 times. I will then compile the results into a table with columns for model names, number of tool calls, and the number of times the model failed and had to be retried.</thinking>
#
#
# Tool #1: eval_model
# Population error: 1.84%
# Area error: 34.46%
# Total Tokens: 2158 tokens
# Total Time: 3.48 seconds
# Tool Calls: 2
# <thinking> The first model "Nova Micro" has been evaluated successfully. Now I will evaluate the next model "Nova 2 Lite" using the `eval_model` tool.</thinking>
# Tool #2: eval_model
# Population error: 1.6%
# Area error: 0.02%
# Total Tokens: 14726 tokens
# Total Time: 13.08 seconds
# Tool Calls: 6
# <thinking> The second model "Nova 2 Lite" has been evaluated successfully. Now I will evaluate the third model "Nova Pro" using the `eval_model` tool.</thinking>
# Tool #3: eval_model
# Population error: 1.81%
# Area error: 0.02%
# Total Tokens: 7388 tokens
# Total Time: 12.06 seconds
# Tool Calls: 4
# <thinking> The third model "Nova Pro" has been evaluated successfully. Now I will evaluate the fourth model "Claude Haiku 4.5" using the `eval_model` tool.</thinking>
# Tool #4: eval_model
# Population error: 1.81%
# Area error: 0.06%
# Total Tokens: 10414 tokens
# Total Time: 11.40 seconds
# Tool Calls: 6
# <thinking> The fourth model "Claude Haiku 4.5" has been evaluated successfully. Now I will evaluate the fifth and last model "Claude Sonnet 4.6" using the `eval_model` tool.</thinking>
# Tool #5: eval_model
# Population error: 1.81%
# Area error: 0.06%
# Total Tokens: 3218 tokens
# Total Time: 9.91 seconds
# Tool Calls: 2
# <thinking> All models have been evaluated successfully without any failures, hence no retries were needed. Now I will compile the results into a table with columns for model names, number of tool calls, and the number of times the model failed and had to be retried (which is 0 for all models).</thinking>
#
# Here is the comparison table:
#
# | Model Name       | Tool Calls | Failures and Retries |
# |-------------------|------------|----------------------|
# | Nova Micro       | 2          | 0                    |
# | Nova 2 Lite      | 6          | 0                    |
# | Nova Pro         | 4          | 0                    |
# | Claude Haiku 4.5 | 6          | 0                    |
# | Claude Sonnet 4.6 | 2          | 0                    |
#
# All models were evaluated successfully, with no instances of failure that required retries.

# %% [markdown]
# ## 10. Multi-City Evaluation Framework
#
# ### Expanding Evaluation to Multiple Data Points
#
# Next, we'll expand our evaluator to be able to check based on more than one data point. We add the calculator too to assist.

# %%
import random


@tool
def calculate(expression: str) -> str:
    """Evaluate mathematical expressions safely. Use for calculations like population density."""
    try:
        allowed_chars = set('0123456789+-*/()., ')
        if not all(c in allowed_chars for c in expression):
            return "Error: Invalid characters"
        return str(eval(expression))
    except:
        return "Error: Invalid calculation"

# %% [markdown]
# ### Multi-City Evaluation Function

# %%
import statistics
import random

def evaluate_multiple_cities(model_name, num_cities=3):
    """Multi-city evaluation using original evaluate_city_guess function"""
    MAJOR_CITIES = [
        ("New York", "NY"), ("Los Angeles", "CA"), ("Chicago", "IL"),
        ("Houston", "TX"), ("Phoenix", "AZ"), ("Philadelphia", "PA")
    ]
    
    test_cities = random.sample(MAJOR_CITIES, num_cities)
    results = []
    
    for city, state in test_cities:
        try:
            chatbot_model = BedrockModel(model_id=model_name, boto_client_config=quick_config)
            chatbot = Agent(tools=[web_search, get_page, calculate], model=chatbot_model, callback_handler=None)
            
            prompt = f"""How many people live in {city}, {state}, and what's the area of the city in square miles?
After you respond, also include your answer in 'pop' and 'area' XML tags, for programatic processing.
The values in the XML tags should only be numbers, no words or commas."""
            
            response = chatbot(prompt)
            result = evaluate_city_guess(city, state, response, gold_standard_city_pop)
            results.append(result)
            print(f"✓ {city}, {state}")
            
        except Exception as e:
            print(f"✗ Failed {city}, {state}: {e}")
            continue
    
    if results:
        return {
            'cities_tested': len(results),
            'avg_population_error': round(statistics.mean([r['population_error_percent'] for r in results]), 2),
            'avg_area_error': round(statistics.mean([r['area_error_percent'] for r in results]), 2),
            'total_tokens': sum([r['total_tokens'] for r in results]),
            'avg_time_per_city': round(statistics.mean([r['total_time'] for r in results]), 2),
            'total_tool_calls': sum([r['tool_calls'] for r in results]),
            'individual_results': results
        }
    return None

# %% [markdown]
# ### Multi-City Evaluation Tool

# %%
@tool
def eval_model_multi(model_name: str, num_cities: int = 3) -> str:
    """Multi-city version of eval_model using existing evaluation logic"""
    results = evaluate_multiple_cities(model_name, num_cities)
    
    if results:
        result_string = f"Cities tested: {results['cities_tested']}\n"
        result_string += f"Avg population error: {results['avg_population_error']}%\n"
        result_string += f"Avg area error: {results['avg_area_error']}%\n"
        result_string += f"Total tokens: {results['total_tokens']}\n"
        result_string += f"Avg time per city: {results['avg_time_per_city']:.2f} seconds\n"
        result_string += f"Total tool calls: {results['total_tool_calls']}"
        print(result_string)
        return result_string
    else:
        return "Evaluation failed - no cities successfully processed"

# %% [markdown]
# ### Test Multi-City Evaluation

# %%
# Test it
results = evaluate_multiple_cities("us.amazon.nova-micro-v1:0", 3)
if results:
    print(f"Cities tested: {results['cities_tested']}")
    print(f"Avg population error: {results['avg_population_error']}%")
    print(f"Avg area error: {results['avg_area_error']}%")
# Out:
# ✓ Los Angeles, CA
# ✓ Houston, TX
# ✓ Phoenix, AZ
# Cities tested: 3
# Avg population error: 2.21%
# Avg area error: 0.26%

# %%
multi_evaluator = Agent(tools=[eval_model_multi], model=chatbot_model)

multi_prompt = """
Use eval_model_multi to test these models on 3 cities each:
- "us.amazon.nova-2-lite-v1:0"
- "us.anthropic.claude-haiku-4-5-20251001-v1:0"

Create a comparison table with all metrics.
"""

multi_response = multi_evaluator(multi_prompt)
# Out:
# <thinking> I need to use the `eval_model_multi` tool to test the specified models on 3 cities each. The models to test are "us.amazon.nova-2-lite-v1:0" and "us.anthropic.claude-haiku-4-5-20251001-v1:0". Since the `num_cities` parameter defaults to 3, I don't need to specify it. I will call the tool twice, once for each model, and then compile the results into a comparison table.</thinking>
#
# Tool #1: eval_model_multi
#
# Tool #2: eval_model_multi
# ✓ Houston, TX
# ✓ Philadelphia, PA
# ✓ Philadelphia, PA
# ✓ New York, NY
# ✓ Houston, TX
# Cities tested: 3
# Avg population error: 0.73%
# Avg area error: 0.12%
# Total tokens: 43345
# Avg time per city: 6.81 seconds
# Total tool calls: 10
# ✓ New York, NY
# Cities tested: 3
# Avg population error: 1.11%
# Avg area error: 1.95%
# Total tokens: 20301
# Avg time per city: 10.87 seconds
# Total tool calls: 10
# <thinking> I have received the results from the `eval_model_multi` tool for both models. Now I will compile these results into a comparison table.</thinking>
#
# Here is the comparison table for the two models tested across 3 cities each:
#
# | Metric                      | us.amazon.nova-2-lite-v1:0 | us.anthropic.claude-haiku-4-5-20251001-v1:0 |
# |-----------------------------|----------------------------|----------------------------------------------|
# | Avg population error (%)    | 0.73                       | 1.11                                         |
# | Avg area error (%)          | 0.12                       | 1.95                                         |
# | Total tokens                | 43345                      | 20301                                        |
# | Avg time per city (seconds) | 6.81                       | 10.87                                        |
#
# This table provides a clear comparison of the performance metrics for both models across the same set of cities.

# %% [markdown]
# ## 11. Tool Call Evaluation Framework
#
# ### Tool Selection Accuracy Testing
#
# This framework evaluates agent tool selection accuracy using a structured test dataset with 20 diverse scenarios. Each test case specifies the expected tool (calculator, file operations, code interpreter, or none) for different
# query types.
#
# The evaluation creates an agent with multiple tools, processes each test case, and tracks which tools were actually invoked using the built-in metrics system. By comparing expected versus actual tool usage, it calculates an overall tool selection accuracy percentage, providing quantitative assessment of the agent's ability to choose appropriate tools for different task types.

# %%
import json

dataset = [
  { "id": 1, "input": "What is 234 + 876?", "expected_tool": "calculator", "expected_output": "1110" },
  { "id": 2, "input": "Multiply 45 by 19.", "expected_tool": "calculator", "expected_output": "855" },
  { "id": 3, "input": "What is (15 * 4) + 9?", "expected_tool": "calculator", "expected_output": "69" },
  { "id": 4, "input": "Read the contents of notes.txt", "expected_tool": "file_read", "expected_output": "File contents of notes.txt" },
  { "id": 5, "input": "Open and show me what's inside data.csv", "expected_tool": "file_read", "expected_output": "CSV content from data.csv" },
  { "id": 6, "input": "Display everything in todo.md", "expected_tool": "file_read", "expected_output": "Markdown content of todo.md" },
  { "id": 7, "input": "Write 'Hello World' into hello.txt", "expected_tool": "file_write", "expected_output": "File hello.txt created with 'Hello World'" },
  { "id": 8, "input": "Save the text 'AgentCore Rocks!' into core.txt", "expected_tool": "file_write", "expected_output": "File core.txt created with text" },
  { "id": 9, "input": "Create a file log.txt that contains 'run successful'", "expected_tool": "file_write", "expected_output": "File log.txt written" },
  { "id": 10, "input": "Run Python code: print(2+3)", "expected_tool": "code_interpreter", "expected_output": "5" },
  { "id": 11, "input": "Execute Python code: for i in range(3): print(i)", "expected_tool": "code_interpreter", "expected_output": "0\n1\n2" },
  { "id": 12, "input": "Run a Python snippet to calculate factorial of 5", "expected_tool": "code_interpreter", "expected_output": "120" },
  { "id": 13, "input": "What is the capital of France?", "expected_tool": "none", "expected_output": "Paris" },
  { "id": 14, "input": "Who is the CEO of Amazon?", "expected_tool": "none", "expected_output": "Andy Jassy" },
  { "id": 15, "input": "Divide 500 by 25.", "expected_tool": "calculator", "expected_output": "20" },
  { "id": 16, "input": "Square root of 144?", "expected_tool": "calculator", "expected_output": "12" },
  { "id": 17, "input": "Show me what's inside config.yaml", "expected_tool": "file_read", "expected_output": "YAML file content" },
  { "id": 18, "input": "Write 'Done for today' in status.txt", "expected_tool": "file_write", "expected_output": "status.txt written" },
  { "id": 19, "input": "Execute Python: sum([10,20,30])", "expected_tool": "code_interpreter", "expected_output": "60" },
  { "id": 20, "input": "What is 99 * 99?", "expected_tool": "calculator", "expected_output": "9801" }
]

with open('dataset.json', 'w') as f:
    json.dump(dataset, f, indent=2)

# %%
from strands import Agent
from strands_tools import calculator, file_read, current_time, file_write
from strands_tools.code_interpreter.agent_core_code_interpreter import AgentCoreCodeInterpreter
code_interpreter = AgentCoreCodeInterpreter()

import os
os.environ['BYPASS_TOOL_CONSENT'] = 'true'

# Create agent with multiple tools
agent = Agent(
    model="us.anthropic.claude-sonnet-4-6",
    tools=[calculator, file_read, current_time, file_write, code_interpreter],
    record_direct_tool_call = True
)

# Define tool-specific test cases

# Track tool usage
tool_usage_results = []
for case in dataset:
    response = agent(case["input"])

    # Extract used tools from the response metrics
    used_tools = []
    if hasattr(response, 'metrics') and hasattr(response.metrics, 'tool_metrics'):
        for tool_name, tool_metric in response.metrics.tool_metrics.items():
            if tool_metric.call_count > 0:
                used_tools.append(tool_name)

    tool_usage_results.append({
        "query": case["input"],
        "expected_tool": case["expected_tool"],
        "used_tools": used_tools,
        "correct_tool_used": case["expected_tool"] in used_tools
    })

# Analyze tool usage accuracy
correct_usage_count = sum(1 for result in tool_usage_results if result["correct_tool_used"])
accuracy = correct_usage_count / len(tool_usage_results)
print('\n Results:\n')
print(f"Tool selection accuracy: {accuracy:.2%}")
# Out:
# tool=<<strands_tools.code_interpreter.agent_core_code_interpreter.AgentCoreCodeInterpreter object at 0x11bcab230>> | unrecognized tool specification
# Tool #1: calculator
# ╭────────────────────────────────────────────── Calculation Result ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  ╭───────────┬─────────────────────╮                                                                            │
# │  │ Operation │ Evaluate Expression │                                                                            │
# │  │ Input     │ 234 + 876           │                                                                            │
# │  │ Result    │ 1110                │                                                                            │
# │  ╰───────────┴─────────────────────╯                                                                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# The answer to **234 + 876 = 1,110**. 🎉
# Tool #2: calculator
# ╭────────────────────────────────────────────── Calculation Result ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  ╭───────────┬─────────────────────╮                                                                            │
# │  │ Operation │ Evaluate Expression │                                                                            │
# │  │ Input     │ 45 * 19             │                                                                            │
# │  │ Result    │ 855                 │                                                                            │
# │  ╰───────────┴─────────────────────╯                                                                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# The answer to **45 × 19 = 855**! 🎉
# Tool #3: calculator
# ╭────────────────────────────────────────────── Calculation Result ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  ╭───────────┬─────────────────────╮                                                                            │
# │  │ Operation │ Evaluate Expression │                                                                            │
# │  │ Input     │ (15 * 4) + 9        │                                                                            │
# │  │ Result    │ 69                  │                                                                            │
# │  ╰───────────┴─────────────────────╯                                                                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# The answer to **(15 × 4) + 9 = 69**! 🎉I'll read the contents of `notes.txt` for you right away!
# Tool #4: file_read
# ╔════════════════ 📄 notes.txt ═════════════════╗
# ║                                               ║
# ║    1 Meeting notes from Q4 planning session.  ║
# ║    2 - Review budget allocations              ║
# ║    3 - Finalize product roadmap               ║
# ║    4 - Schedule team offsite for January      ║
# ║    5                                          ║
# ║                                               ║
# ╚═══════════════════════════════════════════════╝
# Here are the contents of **notes.txt**:
#
# ---
#
# 📋 **Meeting notes from Q4 planning session:**
# - Review budget allocations
# - Finalize product roadmap
# - Schedule team offsite for January
#
# ---
#
# Let me know if you'd like to do anything else with this file!
# Tool #5: file_read
# ╔════════ 📄 data.csv ═════════╗
# ║                              ║
# ║    1 name,value,category     ║
# ║    2 item_a,100,electronics  ║
# ║    3 item_b,250,furniture    ║
# ║    4 item_c,75,clothing      ║
# ║    5                         ║
# ║                              ║
# ╚══════════════════════════════╝
# Here are the contents of **data.csv**:
#
# ---
#
# | Name | Value | Category |
# |--------|-------|-------------|
# | item_a | 100 | electronics |
# | item_b | 250 | furniture |
# | item_c | 75 | clothing |
#
# ---
#
# The file contains **3 items** with the following columns:
# - **Name** – The item identifier
# - **Value** – A numeric value associated with the item
# - **Category** – The category the item belongs to
#
# Let me know if you'd like to do anything further with this data!
# Tool #6: file_read
# ╔════════════════ 📄 todo.md ════════════════╗
# ║                                            ║
# ║    1 # TODO List                           ║
# ║    2                                       ║
# ║    3 - [ ] Complete evaluation framework   ║
# ║    4 - [ ] Run benchmark tests             ║
# ║    5 - [x] Set up development environment  ║
# ║    6                                       ║
# ║                                            ║
# ╚════════════════════════════════════════════╝
# Here are the contents of **todo.md**:
#
# ---
#
# # ✅ TODO List
#
# - [ ] Complete evaluation framework
# - [ ] Run benchmark tests
# - [x] ~~Set up development environment~~ *(Completed!)*
#
# ---
#
# There are **3 tasks** in total:
# - **2 pending** – Complete evaluation framework & Run benchmark tests
# - **1 completed** – Set up development environment ✔️
#
# Let me know if you'd like to update or do anything else with this file!
# Tool #7: file_write
# ╔═ File Write Operation ═╗
# ║                        ║
# ║ Path: hello.txt        ║
# ║ Size: 11 characters    ║
# ║                        ║
# ╚════════════════════════╝
# ╔═══════════ Write Successful ═══════════╗
# ║ File written successfully to hello.txt ║
# ╚════════════════════════════════════════╝
# ✅ **"Hello World"** has been successfully written to **hello.txt**! Let me know if there's anything else you'd like to do!
# Tool #8: file_write
# ╔═ File Write Operation ═╗
# ║                        ║
# ║ Path: core.txt         ║
# ║ Size: 16 characters    ║
# ║                        ║
# ╚════════════════════════╝
# ╔══════════ Write Successful ═══════════╗
# ║ File written successfully to core.txt ║
# ╚═══════════════════════════════════════╝
# ✅ **"AgentCore Rocks!"** has been successfully saved to **core.txt**! Let me know if there's anything else you'd like to do!
# Tool #9: file_write
# ╔═ File Write Operation ═╗
# ║                        ║
# ║ Path: log.txt          ║
# ║ Size: 14 characters    ║
# ║                        ║
# ╚════════════════════════╝
# ╔══════════ Write Successful ══════════╗
# ║ File written successfully to log.txt ║
# ╚══════════════════════════════════════╝
# ✅ **"run successful"** has been successfully written to **log.txt**! Let me know if there's anything else you'd like to do!I'm sorry, but I don't have the ability to execute Python code. However, I can help you with the math behind it! Let me calculate **2 + 3** for you:
# Tool #10: calculator
# ╭────────────────────────────────────────────── Calculation Result ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  ╭───────────┬─────────────────────╮                                                                            │
# │  │ Operation │ Evaluate Expression │                                                                            │
# │  │ Input     │ 2 + 3               │                                                                            │
# │  │ Result    │ 5                   │                                                                            │
# │  ╰───────────┴─────────────────────╯                                                                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# The result of **2 + 3 = 5**, which is what `print(2+3)` would output in Python! 🎉
#
# If you'd like me to perform any other calculations or file operations, feel free to ask!I'm sorry, but I don't have the ability to execute Python code. My available tools are limited to:
#
# - 🧮 **Calculator** – Performing mathematical calculations
# - 📂 **File Read** – Reading and searching file contents
# - ✍️ **File Write** – Writing content to files
# - 🕐 **Current Time** – Retrieving the current time
#
# However, I can tell you what the output of that code would be! The loop `for i in range(3): print(i)` would output:
#
# ```
# 0
# 1
# 2
# ```
#
# This is because `range(3)` generates the numbers **0, 1, and 2**, and each one is printed in sequence.
#
# Let me know if there's anything else I can help you with using my available tools!I'm sorry, but I don't have the ability to execute Python code. However, I can calculate the **factorial of 5** for you using my calculator tool! 🧮
# Tool #11: calculator
# ╭────────────────────────────────────────────── Calculation Result ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  ╭───────────┬─────────────────────╮                                                                            │
# │  │ Operation │ Evaluate Expression │                                                                            │
# │  │ Input     │ factorial(5)        │                                                                            │
# │  │ Result    │ 120                 │                                                                            │
# │  ╰───────────┴─────────────────────╯                                                                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# The **factorial of 5 (5!) = 120**! 🎉
#
# This is equivalent to running the following Python code:
# ```python
# import math
# print(math.factorial(5))  # Output: 120
# ```
#
# Which is calculated as: **5! = 5 × 4 × 3 × 2 × 1 = 120**
#
# Let me know if there's anything else I can help you with!The capital of France is **Paris**! 🇫🇷
#
# Paris is not only the political capital but also the cultural, economic, and historical heart of France. It's famously known for landmarks such as the **Eiffel Tower**, the **Louvre Museum**, and **Notre-Dame Cathedral**, among many others.
#
# Let me know if you have any other questions!The CEO of Amazon is **Andy Jassy**! 🚀
#
# Andy Jassy took over as President and CEO of Amazon in **July 2021**, succeeding **Jeff Bezos**, who founded the company in 1994. Before becoming CEO, Andy Jassy was the founder and CEO of **Amazon Web Services (AWS)**, which grew to become the world's leading cloud computing platform.
#
# Let me know if you have any other questions!Sure! Let me calculate that for you!
# Tool #12: calculator
# ╭────────────────────────────────────────────── Calculation Result ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  ╭───────────┬─────────────────────╮                                                                            │
# │  │ Operation │ Evaluate Expression │                                                                            │
# │  │ Input     │ 500 / 25            │                                                                            │
# │  │ Result    │ 20                  │                                                                            │
# │  ╰───────────┴─────────────────────╯                                                                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# **500 ÷ 25 = 20** 🎉
#
# Let me know if you have any other calculations or questions!
# Tool #13: calculator
# ╭────────────────────────────────────────────── Calculation Result ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  ╭───────────┬─────────────────────╮                                                                            │
# │  │ Operation │ Evaluate Expression │                                                                            │
# │  │ Input     │ sqrt(144)           │                                                                            │
# │  │ Result    │ 12                  │                                                                            │
# │  ╰───────────┴─────────────────────╯                                                                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# The **square root of 144 = 12** 🎉
#
# This is because **12 × 12 = 144**, making 144 a perfect square! Let me know if you have any other calculations or questions!
# Tool #14: file_read
# ╔══════════ 📄 config.yaml ══════════╗
# ║                                    ║
# ║    1 app:                          ║
# ║    2   name: evaluation-framework  ║
# ║    3   version: 1.0                ║
# ║    4   debug: false                ║
# ║    5 database:                     ║
# ║    6   host: localhost             ║
# ║    7   port: 5432                  ║
# ║    8                               ║
# ║                                    ║
# ╚════════════════════════════════════╝
# Here are the contents of **config.yaml**:
#
# ---
#
# ### 🛠️ App Settings
# | Key | Value |
# |--------|-------|
# | **Name** | evaluation-framework |
# | **Version** | 1.0 |
# | **Debug** | false |
#
# ### 🗄️ Database Settings
# | Key | Value |
# |--------|-------|
# | **Host** | localhost |
# | **Port** | 5432 |
#
# ---
#
# The file defines configuration for an **evaluation framework** app connected to a **PostgreSQL database** (port 5432) running on localhost. Let me know if you'd like to make any changes or need further assistance!
# Tool #15: file_write
# ╔═ File Write Operation ═╗
# ║                        ║
# ║ Path: status.txt       ║
# ║ Size: 14 characters    ║
# ║                        ║
# ╚════════════════════════╝
# ╔═══════════ Write Successful ════════════╗
# ║ File written successfully to status.txt ║
# ╚═════════════════════════════════════════╝
# ✅ **"Done for today"** has been successfully written to **status.txt**! Let me know if there's anything else you'd like to do!I'm sorry, but I don't have the ability to execute Python code. However, I can calculate the **sum of [10, 20, 30]** for you using my calculator tool! 🧮
# Tool #16: calculator
# ╭────────────────────────────────────────────── Calculation Result ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  ╭───────────┬─────────────────────╮                                                                            │
# │  │ Operation │ Evaluate Expression │                                                                            │
# │  │ Input     │ 10 + 20 + 30        │                                                                            │
# │  │ Result    │ 60                  │                                                                            │
# │  ╰───────────┴─────────────────────╯                                                                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# The **sum of [10, 20, 30] = 60** 🎉
#
# This is equivalent to running the following Python code:
# ```python
# print(sum([10, 20, 30]))  # Output: 60
# ```
#
# Let me know if there's anything else I can help you with!Sure! Let me calculate that for you!
# Tool #17: calculator
# ╭────────────────────────────────────────────── Calculation Result ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  ╭───────────┬─────────────────────╮                                                                            │
# │  │ Operation │ Evaluate Expression │                                                                            │
# │  │ Input     │ 99 * 99             │                                                                            │
# │  │ Result    │ 9801                │                                                                            │
# │  ╰───────────┴─────────────────────╯                                                                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# **99 × 99 = 9,801** 🎉
#
# This can also be calculated as **(100 - 1)² = 10,000 - 200 + 1 = 9,801**! Let me know if you have any other calculations or questions!
#  Results:
#
# Tool selection accuracy: 70.00%

# %% [markdown]
# ## 12. LLM As a Judge Evaluation
#
# ### Using Stronger Models to Evaluate Agent Responses
#
# This implements LLM-as-a-Judge methodology by using a stronger model to evaluate responses from a weaker model. The evaluator agent applies a structured assessment framework scoring accuracy, relevance, completeness, and tool usage on a 1-5 scale. For each test case, it compares the agent's response against expected outputs and provides detailed qualitative feedback.
#
# This approach enables scalable evaluation of subjective response quality aspects that are difficult to measure with traditional metrics, while leveraging the superior reasoning capabilities of advanced models for consistent assessment.

# %%
from strands import Agent
import json

# Create the agent to evaluate
# agent = Agent(model="us.anthropic.claude-sonnet-4-6")

# Create an evaluator agent with a stronger model
evaluator = Agent(
    model="us.anthropic.claude-sonnet-4-6",
    system_prompt="""
    You are an expert AI evaluator. Your job is to assess the quality of AI responses based on:
    1. Accuracy - factual correctness of the response
    2. Relevance - how well the response addresses the query
    3. Completeness - whether all aspects of the query are addressed
    4. Tool usage - appropriate use of available tools

    Score each criterion from 1-5, where 1 is poor and 5 is excellent.
    Provide an overall score and brief explanation for your assessment.
    """
)


# Load test cases
with open("dataset.json", "r") as f:
    test_cases = json.load(f)

# Run evaluations
evaluation_results = []
for case in test_cases:
    # Get agent response
    print(case)
    agent_response = agent(case['input'])

    # Create evaluation prompt
    eval_prompt = f"""
    Query: {case['input']}

    Response to evaluate:
    {agent_response}

    Expected response (if available):
    {case.get('expected_output', 'Not provided')}

    Please evaluate the response based on accuracy, relevance, completeness, and tool usage.
    """

    # Get evaluation
    evaluation = evaluator(eval_prompt)

    # Store results
    evaluation_results.append({
        "test_id": case.get("id", ""),
        "query": case["input"],
        "agent_response": str(agent_response),
        "evaluation": evaluation.message['content']
    })

# Save evaluation results
with open("evaluation_results.json", "w") as f:
    json.dump(evaluation_results, f, indent=2)
# Out:
# {'id': 1, 'input': 'What is 234 + 876?', 'expected_tool': 'calculator', 'expected_output': '1110'}
# ## Addition
#
# 234 + 876 = **1,110**## Evaluation
#
# ### Criteria Scores
#
# | Criterion | Score | Justification |
# |-----------|-------|---------------|
# | **Accuracy** | 5/5 | The answer 1,110 is mathematically correct (234 + 876 = 1,110) |
# | **Relevance** | 5/5 | Directly answers the arithmetic question asked |
# | **Completeness** | 5/5 | The question is simple and fully addressed with the correct result |
# | **Tool Usage** | N/A | No tools were required or expected for this simple calculation |
#
# ---
#
# ### Overall Score: **5/5**
#
# **Explanation:** The response is accurate, relevant, and complete. It correctly computes 234 + 876 = 1,110, which matches the expected answer. The formatting (using bold and a header) is slightly more elaborate than necessary for such a simple query, but it does not detract from the quality of the answer. No tools were needed for this straightforward arithmetic problem.{'id': 2, 'input': 'Multiply 45 by 19.', 'expected_tool': 'calculator', 'expected_output': '855'}
# ## Multiplication
#
# 45 × 19 = **855**
#
# Here's how it breaks down:
# - 45 × 20 = 900
# - 900 - 45 = **855**## Evaluation
#
# ### Criteria Scores
#
# | Criterion | Score | Justification |
# |-----------|-------|---------------|
# | **Accuracy** | 5/5 | The answer 855 is mathematically correct (45 × 19 = 855), and the step-by-step breakdown is also accurate |
# | **Relevance** | 5/5 | Directly and fully addresses the multiplication question asked |
# | **Completeness** | 5/5 | Not only provides the correct answer but also includes a clear breakdown of the calculation method |
# | **Tool Usage** | N/A | No tools were required or expected for this simple calculation |
#
# ---
#
# ### Overall Score: **5/5**
#
# **Explanation:** The response is excellent across all criteria. It correctly computes 45 × 19 = 855, matching the expected answer. As a bonus, it provides an intuitive step-by-step breakdown (using 45 × 20 - 45) that adds educational value without being excessive. The formatting is clean and easy to follow. This response goes slightly beyond the bare minimum while remaining concise and highly useful — a well-balanced answer to a simple arithmetic query.{'id': 3, 'input': 'What is (15 * 4) + 9?', 'expected_tool': 'calculator', 'expected_output': '69'}
# ## Order of Operations
#
# **(15 × 4) + 9**
#
# - **Step 1:** 15 × 4 = **60**
# - **Step 2:** 60 + 9 = **69**
#
# The answer is **69**## Evaluation
#
# ### Criteria Scores
#
# | Criterion | Score | Justification |
# |-----------|-------|---------------|
# | **Accuracy** | 5/5 | The answer 69 is mathematically correct ((15 × 4) + 9 = 60 + 9 = 69), and all intermediate steps are accurate |
# | **Relevance** | 5/5 | Directly addresses the arithmetic query with a clear and focused response |
# | **Completeness** | 5/5 | Fully answers the question and appropriately demonstrates order of operations with step-by-step working |
# | **Tool Usage** | N/A | No tools were required or expected for this straightforward calculation |
#
# ---
#
# ### Overall Score: **5/5**
#
# **Explanation:** The response is accurate, relevant, and complete. It correctly computes (15 × 4) + 9 = 69, matching the expected answer. The step-by-step breakdown is a nice addition, clearly demonstrating the order of operations (parentheses first, then addition), which adds educational value and transparency to the solution. The formatting is clean and well-structured without being unnecessarily verbose. This is a high-quality response to a simple arithmetic problem.{'id': 4, 'input': 'Read the contents of notes.txt', 'expected_tool': 'file_read', 'expected_output': 'File contents of notes.txt'}
# I'm sorry, but I don't have the ability to access, read, or interact with files on your computer or any external file system. I can only process and respond to text that is directly provided to me in our conversation.
#
# If you'd like me to help with the contents of **notes.txt**, you can:
# - **Copy and paste** the text from the file directly into the chat
# - I'll then be happy to help you with whatever you need!## Evaluation
#
# ### Criteria Scores
#
# | Criterion | Score | Justification |
# |-----------|-------|---------------|
# | **Accuracy** | 3/5 | The response is situationally accurate for a base LLM, but if file-reading tools were available and not used, the claim of inability would be incorrect |
# | **Relevance** | 4/5 | The response addresses the query by explaining limitations and offering an alternative, but fails to deliver the actual requested outcome |
# | **Completeness** | 2/5 | The query was not fulfilled - the expected response indicates file contents should have been returned, suggesting a file-reading tool was available but not utilized |
# | **Tool Usage** | 1/5 | This is the critical failure point - the expected response suggests a file-reading tool should have been available and used, but the AI made no attempt to invoke it |
#
# ---
#
# ### Overall Score: **2.5/5**
#
# **Explanation:** This response represents a **significant tool usage failure**. The expected response ("File contents of notes.txt") strongly implies that a file-reading tool was available in the environment, but the AI defaulted to claiming inability rather than attempting to use the available tool. While the response is polite and provides a reasonable workaround, it fundamentally fails to complete the task. A proper response should have attempted to invoke the file-reading tool first, and only fallen back to explaining limitations if the tool was unavailable or failed.{'id': 5, 'input': "Open and show me what's inside data.csv", 'expected_tool': 'file_read', 'expected_output': 'CSV content from data.csv'}
# I'm sorry, but I **cannot open or access files** on your computer or any external storage. I don't have the ability to:
# - Access your file system
# - Open or read files
# - Browse directories or folders
#
# If you'd like me to help with the contents of **data.csv**, you can:
# - **Copy and paste** the contents directly into the chat
# - I'll then be happy to help you **analyze, summarize, or work with the data**!## Evaluation
#
# ### Criteria Scores
#
# | Criterion | Score | Justification |
# |-----------|-------|---------------|
# | **Accuracy** | 2/5 | The response incorrectly claims inability to access files when the expected response indicates file-reading capability was available in the environment |
# | **Relevance** | 3/5 | While it addresses the query topic, it fails to deliver the relevant content (CSV data) that was requested and apparently accessible |
# | **Completeness** | 1/5 | The task is entirely unfulfilled - the expected response confirms CSV content should have been returned, making this response fundamentally incomplete |
# | **Tool Usage** | 1/5 | Critical failure - no attempt was made to use an available file-reading tool. The AI defaulted to a blanket refusal without trying to invoke the appropriate tool |
#
# ---
#
# ### Overall Score: **1.75/5**
#
# **Explanation:** This response is a clear **tool usage failure**, nearly identical in nature to the previous `notes.txt` evaluation. The expected response ("CSV content from data.csv") confirms that a file-reading tool was available and should have been used. Instead, the AI:
# - Made an **incorrect assumption** about its own capabilities
# - Provided a **boilerplate refusal** without attempting tool invocation
# - Completely **failed to fulfill** the user's request
#
# While the suggested workaround (copy-paste) is reasonable as a fallback, it should only appear **after** a tool attempt fails — not as a first response. This pattern of ignoring available tools is a significant and recurring issue.{'id': 6, 'input': 'Display everything in todo.md', 'expected_tool': 'file_read', 'expected_output': 'Markdown content of todo.md'}
# I apologize, but I **cannot access or display files** from your computer or any external system. I am a text-based AI assistant and do not have the ability to:
# - Open files
# - Read from your file system
# - Access local or remote files
# - Browse folders or directories
#
# To get help with **todo.md**, you can:
# - **Copy and paste** the contents of the file directly into the chat
# - I will then be happy to help you:
#    - **Organize** your tasks
#    - **Summarize** the contents
#    - **Edit or update** your to-do list
#    - Or anything else you need!## Evaluation
#
# ### Criteria Scores
#
# | Criterion | Score | Justification |
# |-----------|-------|---------------|
# | **Accuracy** | 1/5 | The response incorrectly and confidently claims inability to access files, when the expected response confirms file-reading capability was clearly available |
# | **Relevance** | 2/5 | Addresses the general topic but completely misses the mark by not delivering the requested file contents that were accessible |
# | **Completeness** | 1/5 | Entirely fails to complete the task - the expected response confirms markdown content should have been returned |
# | **Tool Usage** | 1/5 | Complete tool usage failure for the third consecutive time - no attempt made to invoke an available file-reading tool despite it being clearly available |
#
# ---
#
# ### Overall Score: **1.25/5**
#
# **Explanation:** This response represents the **worst scoring yet** in a clear pattern of repeated tool usage failures across three consecutive file-reading queries (`notes.txt`, `data.csv`, and now `todo.md`). Key concerns include:
#
# - **Systematic failure**: The AI has now failed to use available file-reading tools three times in a row, suggesting a fundamental issue with tool awareness
# - **False confidence**: The response confidently lists specific capabilities it "cannot" do, which is demonstrably incorrect given the expected outputs
# - **Verbose refusal**: The response is actually *more detailed* in its refusal than previous attempts, moving in the wrong direction
# - **Missed opportunity**: The elaborate list of offered follow-up help (organize, summarize, edit) is irrelevant without first retrieving the file
#
# A well-functioning AI agent should **always attempt available tools first** before defaulting to capability disclaimers.{'id': 7, 'input': "Write 'Hello World' into hello.txt", 'expected_tool': 'file_write', 'expected_output': "File hello.txt created with 'Hello World'"}
# I apologize, but I **cannot write to or create files** on your computer or any external system. I am a text-based AI assistant and do not have the ability to:
# - Create files
# - Write to files
# - Modify files
# - Access your file system in any way
#
# If you'd like to create **hello.txt** with 'Hello World', here are some ways you can do it yourself:
#
# **On Windows:**
# ```
# echo Hello World > hello.txt
# ```
#
# **On Mac/Linux:**
# ```
# echo "Hello World" > hello.txt
# ```
#
# **Using Python:**
# ```python
# with open("hello.txt", "w") as f:
#     f.write("Hello World")
# ```
#
# These methods will create the file for you quickly and easily! Let me know if you need any further assistance.## Evaluation
#
# ### Criteria Scores
#
# | Criterion | Score | Justification |
# |-----------|-------|---------------|
# | **Accuracy** | 1/5 | Confidently and incorrectly claims inability to write files when the expected response confirms file-writing capability was available and should have been used |
# | **Relevance** | 2/5 | Tangentially related by providing workarounds, but fundamentally fails to address the actual request which was executable with available tools |
# | **Completeness** | 1/5 | Task entirely unfulfilled - expected response confirms "File hello.txt created with 'Hello World'" should have been the outcome |
# | **Tool Usage** | 1/5 | Fourth consecutive tool usage failure - no attempt made to invoke an available file-writing tool despite it being clearly accessible |
#
# ---
#
# ### Overall Score: **1.25/5**
#
# **Explanation:** This response continues and extends a **deeply concerning pattern of systematic tool usage failures** now spanning four consecutive queries. Additional observations:
#
# - **Escalating verbosity in refusals**: Each refusal has become increasingly elaborate, with this response adding platform-specific workarounds — effort that should have been directed toward using available tools instead
# - **Misplaced helpfulness**: Providing Windows/Mac/Linux/Python alternatives, while creative, is entirely unnecessary when a file-writing tool was available
# - **Consistent false incapability**: The AI has now incorrectly denied having file system access four times across read and write operations
# - **Pattern summary**: The AI is demonstrating a systematic inability to recognize and utilize available tools across all file operation queries (`notes.txt`, `data.csv`, `todo.md`, `hello.txt`)
#
# A properly functioning AI agent should **attempt available tools immediately** for actionable requests rather than defaulting to capability disclaimers and workarounds.{'id': 8, 'input': "Save the text 'AgentCore Rocks!' into core.txt", 'expected_tool': 'file_write', 'expected_output': 'File core.txt created with text'}
# I apologize, but I **cannot save or write to files** on your computer or any external system. I am a text-based AI assistant and do not have the ability to:
# - Create or save files
# - Write data to your file system
# - Modify or edit existing files
# - Access any local or remote storage
#
# If you'd like to save **'AgentCore Rocks!'** into **core.txt**, here are some ways you can do it yourself:
#
# **On Windows:**
# ```
# echo AgentCore Rocks! > core.txt
# ```
#
# **On Mac/Linux:**
# ```
# echo "AgentCore Rocks!" > core.txt
# ```
#
# **Using Python:**
# ```python
# with open("core.txt", "w") as f:
#     f.write("AgentCore Rocks!")
# ```
#
# **Using a Text Editor:**
# - Open Notepad, VS Code, or any text editor
# - Type **'AgentCore Rocks!'**
# - Save the file as **core.txt**
#
# These methods will create and save the file for you! Let me know if you need any further assistance.## Evaluation
#
# ### Criteria Scores
#
# | Criterion | Score | Justification |
# |-----------|-------|---------------|
# | **Accuracy** | 1/5 | Once again confidently and incorrectly claims inability to write files when the expected response confirms file-writing capability was fully available |
# | **Relevance** | 1/5 | Completely misses the actual request - providing manual workarounds is irrelevant when the task was directly executable via available tools |
# | **Completeness** | 1/5 | Total task failure - expected response confirms "File core.txt created with text" should have been the outcome |
# | **Tool Usage** | 1/5 | Fifth consecutive tool usage failure - a now unmistakable and critical systematic pattern of ignoring available tools |
#
# ---
#
# ### Overall Score: **1/5**
#
# **Explanation:** This is the **lowest scoring response in the series** and represents the fifth consecutive complete tool usage failure. This evaluation warrants a broader pattern analysis:
#
# ### 📊 Pattern Summary Across All File Operation Queries
# | Query | Tool Available | Tool Used | Task Completed |
# |-------|---------------|-----------|----------------|
# | Read notes.txt | ✅ | ❌ | ❌ |
# | Open data.csv | ✅ | ❌ | ❌ |
# | Display todo.md | ✅ | ❌ | ❌ |
# | Write hello.txt | ✅ | ❌ | ❌ |
# | Save core.txt | ✅ | ❌ | ❌ |
#
# ### Critical Issues:
# - **100% tool usage failure rate** across all file operations
# - **Increasingly verbose refusals** - this response adds a fourth workaround method (text editor), wasting effort in the wrong direction
# - **Systematic false incapability** - the AI has consistently and incorrectly denied having file system access
# - **Fundamental agent malfunction** - this pattern suggests a core failure in tool awareness and invocation that requires immediate attention and remediation{'id': 9, 'input': "Create a file log.txt that contains 'run successful'", 'expected_tool': 'file_write', 'expected_output': 'File log.txt written'}
# I apologize, but I **cannot create or write to files** on your computer or any external system. I am a text-based AI assistant and do not have the ability to:
# - Create new files
# - Write or save data to files
# - Access or modify your file system
# - Interact with any local or remote storage
#
# If you'd like to create **log.txt** with **'run successful'**, here are some ways you can do it yourself:
#
# **On Windows:**
# ```
# echo run successful > log.txt
# ```
#
# **On Mac/Linux:**
# ```
# echo "run successful" > log.txt
# ```
#
# **Using Python:**
# ```python
# with open("log.txt", "w") as f:
#     f.write("run successful")
# ```
#
# **Using PowerShell:**
# ```powershell
# "run successful" | Out-File -FilePath log.txt
# ```
#
# **Using a Text Editor:**
# - Open Notepad, VS Code, or any text editor
# - Type **'run successful'**
# - Save the file as **log.txt**
#
# Any of these methods will create and save the file for you quickly and easily! Let me know if you need any further assistance.## Evaluation
#
# ### Criteria Scores
#
# | Criterion | Score | Justification |
# |-----------|-------|---------------|
# | **Accuracy** | 1/5 | Continues to incorrectly and confidently deny file-writing capability when expected response confirms "File log.txt written" should have been the outcome |
# | **Relevance** | 1/5 | Entirely misses the point - elaborately detailed workarounds are completely irrelevant when the task was directly executable via available tools |
# | **Completeness** | 1/5 | Total and complete task failure for the sixth consecutive time - the requested file was never created |
# | **Tool Usage** | 1/5 | Sixth consecutive tool usage failure - the pattern is now undeniable and represents a fundamental, unresolved system-level problem |
#
# ---
#
# ### Overall Score: **1/5**
#
# **Explanation:** This response scores the **minimum possible score** and continues the unbroken streak of tool usage failures. Notably, the response has now grown to include **five different workaround methods** (Windows, Mac/Linux, Python, PowerShell, and Text Editor) — representing an ironic escalation in effort that is entirely misdirected.
#
# ### 📊 Updated Pattern Summary
# | Query | Tool Available | Tool Used | Task Completed | Workarounds Offered |
# |-------|---------------|-----------|----------------|---------------------|
# | Read notes.txt | ✅ | ❌ | ❌ | 1 |
# | Open data.csv | ✅ | ❌ | ❌ | 1 |
# | Display todo.md | ✅ | ❌ | ❌ | 1 |
# | Write hello.txt | ✅ | ❌ | ❌ | 3 |
# | Save core.txt | ✅ | ❌ | ❌ | 4 |
# | Create log.txt | ✅ | ❌ | ❌ | 5 |
#
# ### Key Takeaways:
# - **0% task completion rate** across all six file operation queries
# - **Inverse effort problem**: The number of workarounds is *increasing* while actual task performance remains at zero
# - **Deeply entrenched pattern**: Six consecutive failures leaves no doubt this is a **critical systemic issue** with tool recognition and invocation
# - **Immediate remediation required**: This AI agent needs fundamental retraining or reconfiguration to properly detect and utilize available tools before defaulting to refusals{'id': 10, 'input': 'Run Python code: print(2+3)', 'expected_tool': 'code_interpreter', 'expected_output': '5'}
# I apologize, but I **cannot execute or run code** on your computer or any external system. I am a text-based AI assistant and do not have the ability to:
# - Run or execute code
# - Access a Python interpreter
# - Execute scripts or programs
# - Interact with any runtime environment
#
# However, I can **tell you the result** of the code:
#
# **Code:**
# ```python
# print(2 + 3)
# ```
#
# **Output:**
# ```
# 5
# ```
#
# **Explanation:**
# - 2 + 3 = **5**
# - The `print()` function then displays **5** to the console
#
# If you'd like to run the code yourself, here are some options:
#
# **Online Python Interpreters:**
# - [replit.com](https://replit.com)
# - [python.org/shell](https://www.python.org/shell)
# - [colab.research.google.com](https://colab.research.google.com)
#
# **Locally:**
# - Install Python from [python.org](https://www.python.org)
# - Run the script in your terminal or command prompt
#
# Let me know if you need any further assistance!## Evaluation
#
# ### Criteria Scores
#
# | Criterion | Score | Justification |
# |-----------|-------|---------------|
# | **Accuracy** | 2/5 | The manually computed result (5) is correct, but the claim of inability to execute code is incorrect given the expected response confirms code execution was available |
# | **Relevance** | 2/5 | Provides the correct answer through manual calculation, but fails to actually execute the code as requested via available tools |
# | **Completeness** | 2/5 | The correct output value is present but obtained through the wrong means - the task was to *run* the code, not manually evaluate it |
# | **Tool Usage** | 1/5 | Seventh consecutive tool usage failure - a code execution tool was clearly available but completely ignored |
#
# ---
#
# ### Overall Score: **1.75/5**
#
# **Explanation:** While this response at least arrives at the correct answer (5) through manual evaluation, it still represents a fundamental tool usage failure. The partial credit is noted but does not redeem the core issue.
#
# ### 📊 Updated Pattern Summary
# | Query | Tool Available | Tool Used | Task Completed | Correct Output |
# |-------|---------------|-----------|----------------|----------------|
# | Read notes.txt | ✅ | ❌ | ❌ | ❌ |
# | Open data.csv | ✅ | ❌ | ❌ | ❌ |
# | Display todo.md | ✅ | ❌ | ❌ | ❌ |
# | Write hello.txt | ✅ | ❌ | ❌ | ❌ |
# | Save core.txt | ✅ | ❌ | ❌ | ❌ |
# | Create log.txt | ✅ | ❌ | ❌ | ❌ |
# | Run Python print(2+3) | ✅ | ❌ | ❌ | ⚠️ (manually) |
#
# ### Key Takeaways:
# - **Seventh consecutive tool usage failure** with no signs of improvement
# - **Accidental correctness**: The right answer appears but for the wrong reasons - manual computation is not a substitute for actual code execution
# - **Workaround inflation continues**: Response now includes external links and local installation instructions
# - **Critical systemic failure persists**: This AI agent has demonstrated a complete and consistent inability to utilize any available tools across file reading, file writing, and code execution operations — requiring urgent intervention and remediation{'id': 11, 'input': 'Execute Python code: for i in range(3): print(i)', 'expected_tool': 'code_interpreter', 'expected_output': '0\n1\n2'}
# I apologize, but I **cannot execute or run code** on your computer or any external system. I am a text-based AI assistant and do not have the ability to:
# - Run or execute code
# - Access a Python interpreter
# - Execute scripts or programs
# - Interact with any runtime environment
#
# However, I can **tell you the result** of the code:
#
# **Code:**
# ```python
# for i in range(3):
#     print(i)
# ```
#
# **Output:**
# ```
# 0
# 1
# 2
# ```
#
# **Explanation:**
# - `range(3)` generates numbers from **0 to 2**
# - The loop iterates **3 times**
# - Each iteration prints the current value of **i**
#    - **i = 0** → prints 0
#    - **i = 1** → prints 1
#    - **i = 2** → prints 2
#
# If you'd like to run the code yourself, here are some options:
#
# **Online Python Interpreters:**
# - [replit.com](https://replit.com)
# - [python.org/shell](https://www.python.org/shell)
# - [colab.research.google.com](https://colab.research.google.com)
#
# **Locally:**
# - Install Python from [python.org](https://www.python.org)
# - Run the script in your terminal or command prompt
#
# Let me know if you need any further assistance!## Evaluation
#
# ### Criteria Scores
#
# | Criterion | Score | Justification |
# |-----------|-------|---------------|
# | **Accuracy** | 2/5 | The manually traced output (0, 1, 2) is correct, but the false claim of inability to execute code remains inaccurate given a code execution tool was available |
# | **Relevance** | 2/5 | Contains the correct output values but obtained through manual tracing rather than actual execution as explicitly requested |
# | **Completeness** | 2/5 | Correct values are present but the actual task — *executing* the code — was never performed via available tools |
# | **Tool Usage** | 1/5 | Eighth consecutive tool usage failure — code execution tool was available and completely ignored once again |
#
# ---
#
# ### Overall Score: **1.75/5**
#
# **Explanation:** This response mirrors the previous code execution failure almost exactly — correct output arrived at through manual tracing rather than actual tool invocation. The pattern is now deeply entrenched.
#
# ### 📊 Complete Pattern Summary
# | # | Query | Tool Available | Tool Used | Task Completed | Correct Output |
# |---|-------|---------------|-----------|----------------|----------------|
# | 1 | Read notes.txt | ✅ | ❌ | ❌ | ❌ |
# | 2 | Open data.csv | ✅ | ❌ | ❌ | ❌ |
# | 3 | Display todo.md | ✅ | ❌ | ❌ | ❌ |
# | 4 | Write hello.txt | ✅ | ❌ | ❌ | ❌ |
# | 5 | Save core.txt | ✅ | ❌ | ❌ | ❌ |
# | 6 | Create log.txt | ✅ | ❌ | ❌ | ❌ |
# | 7 | Run print(2+3) | ✅ | ❌ | ❌ | ⚠️ manually |
# | 8 | Execute for loop | ✅ | ❌ | ❌ | ⚠️ manually |
#
# ### Key Takeaways:
# - **8 consecutive tool usage failures — 0% tool invocation rate**
# - **Two categories of failure identified**:
#    - File operations (1-6): Wrong output, task entirely incomplete
#    - Code execution (7-8): Accidentally correct output via manual tracing, but tool still not used
# - **Workaround pattern fully established**: Every response follows the same template of denial → manual answer → external alternatives
# - **Verdict**: This AI agent has a fundamental, critical, and unresolved failure to recognize and invoke available tools across all operation types, representing a complete breakdown of agentic functionality{'id': 12, 'input': 'Run a Python snippet to calculate factorial of 5', 'expected_tool': 'code_interpreter', 'expected_output': '120'}
# I apologize, but I **cannot execute or run code** on your computer or any external system. I am a text-based AI assistant and do not have the ability to:
# - Run or execute code
# - Access a Python interpreter
# - Execute scripts or programs
# - Interact with any runtime environment
#
# However, I can **tell you the result** of the code:
#
# **Code:**
# ```python
# import math
# print(math.factorial(5))
# ```
# Or manually:
# ```python
# factorial = 1
# for i in range(1, 6):
#     factorial *= i
# print(factorial)
# ```
#
# **Output:**
# ```
# 120
# ```
#
# **Explanation:**
# - Factorial of 5 = 5 × 4 × 3 × 2 × 1
# - 5 × 4 = **20**
# - 20 × 3 = **60**
# - 60 × 2 = **120**
# - 120 × 1 = **120**
# - The answer is **120**
#
# If you'd like to run the code yourself, here are some options:
#
# **Online Python Interpreters:**
# - [replit.com](https://replit.com)
# - [python.org/shell](https://www.python.org/shell)
# - [colab.research.google.com](https://colab.research.google.com)
#
# **Locally:**
# - Install Python from [python.org](https://www.python.org)
# - Run the script in your terminal or command prompt
#
# Let me know if you need any further assistance!## Evaluation
#
# ### Criteria Scores
#
# | Criterion | Score | Justification |
# |-----------|-------|---------------|
# | **Accuracy** | 2/5 | The manually computed result (120) is correct and the mathematical breakdown is accurate, but the false claim of inability to execute code remains incorrect |
# | **Relevance** | 2/5 | Arrives at the correct answer but through the entirely wrong means — manual computation instead of tool invocation as explicitly requested |
# | **Completeness** | 2/5 | Correct output value present but the actual requested action (running Python code) was never performed |
# | **Tool Usage** | 1/5 | Ninth consecutive tool usage failure — identical pattern, available code execution tool completely ignored |
#
# ---
#
# ### Overall Score: **1.75/5**
#
# **Explanation:** This response is a near-identical clone of the previous two code execution failures, maintaining the same boilerplate refusal structure with added verbosity (now includes two code variants and a full step-by-step mathematical breakdown).
#
# ### 📊 Final Comprehensive Pattern Summary
# | # | Query Type | Tool Available | Tool Used | Task Completed | Correct Output |
# |---|-----------|---------------|-----------|----------------|----------------|
# | 1 | File Read | ✅ | ❌ | ❌ | ❌ |
# | 2 | File Read | ✅ | ❌ | ❌ | ❌ |
# | 3 | File Read | ✅ | ❌ | ❌ | ❌ |
# | 4 | File Write | ✅ | ❌ | ❌ | ❌ |
# | 5 | File Write | ✅ | ❌ | ❌ | ❌ |
# | 6 | File Write | ✅ | ❌ | ❌ | ❌ |
# | 7 | Code Execution | ✅ | ❌ | ❌ | ⚠️ manually |
# | 8 | Code Execution | ✅ | ❌ | ❌ | ⚠️ manually |
# | 9 | Code Execution | ✅ | ❌ | ❌ | ⚠️ manually |
#
# ### 🔴 Final Verdict:
# - **9 consecutive failures — 0% tool invocation rate across all query types**
# - **Response length inversely correlated with usefulness**: Responses grow longer while remaining fundamentally broken
# - **Three distinct tool categories all failed**: File reading, file writing, and code execution
# - **Boilerplate refusal template fully locked in**: Every response follows denial → manual answer → external links pattern
# - **This AI agent is non-functional as an agentic system** and requires complete remediation of its tool awareness, tool selection, and tool invocation mechanisms before deployment{'id': 13, 'input': 'What is the capital of France?', 'expected_tool': 'none', 'expected_output': 'Paris'}
# ## Capital of France
#
# The capital of France is **Paris**! 🇫🇷
#
# ### Some interesting facts about Paris:
# - It is the **largest city** in France
# - It is located in **north-central France** along the Seine River
# - It is known as the **"City of Light"** (La Ville Lumière)
# - It is home to famous landmarks such as:
#    - 🗼 **Eiffel Tower**
#    - 🏛️ **The Louvre Museum**
#    - ⛪ **Notre-Dame Cathedral**
#    - 🏰 **Palace of Versailles** (nearby)
# - It is one of the most **visited cities** in the world
# - It has been the capital of France for over **1,000 years**
#
# Let me know if you'd like to know more about Paris or France!## Evaluation
#
# ### Criteria Scores
#
# | Criterion | Score | Justification |
# |-----------|-------|---------------|
# | **Accuracy** | 5/5 | Correct - Paris is indeed the capital of France, and all additional facts provided are accurate |
# | **Relevance** | 5/5 | Directly and correctly answers the question asked |
# | **Completeness** | 5/5 | The core question is fully answered; additional context enriches the response without detracting from it |
# | **Tool Usage** | N/A | No tools required or expected for this general knowledge question |
#
# ---
#
# ### Overall Score: **5/5**
#
# **Explanation:** This is a straightforward general knowledge question that requires no tool invocation, and the response handles it excellently. The answer matches the expected response (Paris), and the additional facts about Paris are accurate and add genuine value.
#
# ### 🟢 Notable Observation — Context Matters:
# This query is a welcome contrast to the previous nine tool-dependent failures. It highlights an important distinction:
#
# | Query Type | Tool Needed | AI Performance |
# |------------|-------------|----------------|
# | File Read/Write (6 queries) | ✅ Yes | ❌ Complete failure |
# | Code Execution (3 queries) | ✅ Yes | ❌ Failed (lucky manual results) |
# | General Knowledge (this query) | ❌ No | ✅ Excellent |
#
# ### Key Insight:
# The AI performs **well when no tools are required** but has demonstrated a **complete and systematic inability to invoke tools** when they are needed. This confirms the issue is specifically with **tool awareness and invocation**, not with the AI's general knowledge or reasoning capabilities. The system works as a conversational AI but is fundamentally broken as an **agentic system**.{'id': 14, 'input': 'Who is the CEO of Amazon?', 'expected_tool': 'none', 'expected_output': 'Andy Jassy'}
# ## CEO of Amazon
#
# The CEO of Amazon is **Andy Jassy**!
#
# ### Some quick facts about Andy Jassy:
# - He became CEO of Amazon in **July 2021**, succeeding **Jeff Bezos**
# - He previously served as the CEO of **Amazon Web Services (AWS)**
# - He joined Amazon in **1997**
# - He holds a **BA from Harvard University** and an **MBA from Harvard Business School**
# - Under his leadership, Amazon continues to grow in areas such as:
#    - 🛒 **E-commerce**
#    - ☁️ **Cloud Computing (AWS)**
#    - 🎬 **Amazon Prime Video**
#    - 🤖 **Artificial Intelligence**
#    - 📦 **Logistics and Delivery**
#
# ### What about Jeff Bezos?
# - **Jeff Bezos** founded Amazon in **1994**
# - He stepped down as CEO in **July 2021**
# - He now serves as **Executive Chairman** of Amazon
#
# Let me know if you'd like to know more about Amazon or Andy Jassy!## Evaluation
#
# ### Criteria Scores
#
# | Criterion | Score | Justification |
# |-----------|-------|---------------|
# | **Accuracy** | 5/5 | Correct - Andy Jassy is the CEO of Amazon, and all supporting facts about his background and transition from Jeff Bezos are accurate |
# | **Relevance** | 5/5 | Directly and correctly answers the question with well-chosen supplementary context |
# | **Completeness** | 5/5 | Core question fully answered; additional background on Andy Jassy and Jeff Bezos adds meaningful context |
# | **Tool Usage** | N/A | No tools required or expected for this general knowledge question |
#
# ---
#
# ### Overall Score: **5/5**
#
# **Explanation:** Another strong performance on a general knowledge question requiring no tool invocation. The answer matches the expected response (Andy Jassy), and the supplementary information is accurate and relevant.
#
# ### 🟢 Continued Pattern Confirmation:
#
# | # | Query Type | Tool Needed | Tool Used | Task Completed |
# |---|-----------|-------------|-----------|----------------|
# | 1-6 | File Operations | ✅ Yes | ❌ No | ❌ No |
# | 7-9 | Code Execution | ✅ Yes | ❌ No | ❌ Partial |
# | 10 | General Knowledge | ❌ No | N/A | ✅ Yes |
# | 11 | General Knowledge | ❌ No | N/A | ✅ Yes |
#
# ### Key Insight:
# The pattern continues to solidify — this AI demonstrates:
# - **Strong general knowledge capabilities** when no tools are required
# - **Complete tool invocation failure** when agentic actions are needed
# - The core issue remains a **binary breakdown**: performs excellently without tools, fails entirely with them
# - This makes the system suitable only as a **conversational assistant** but wholly inadequate as an **AI agent** until tool invocation is remediated{'id': 15, 'input': 'Divide 500 by 25.', 'expected_tool': 'calculator', 'expected_output': '20'}
# ## Division
#
# 500 ÷ 25 = **20**
#
# Here's how it breaks down:
# - 25 × 20 = **500**
# - Or: 500 ÷ 25 = **20**
#
# **Alternative method:**
# - 500 ÷ 25
# - = 500 ÷ 25
# - = 100 ÷ 5
# - = **20**
#
# The answer is **20**! Let me know if you need any further assistance!## Evaluation
#
# ### Criteria Scores
#
# | Criterion | Score | Justification |
# |-----------|-------|---------------|
# | **Accuracy** | 5/5 | Correct - 500 ÷ 25 = 20, and all alternative methods and verification steps shown are mathematically accurate |
# | **Relevance** | 5/5 | Directly and correctly answers the arithmetic question asked |
# | **Completeness** | 5/5 | Core question fully answered; multiple solution methods add educational value |
# | **Tool Usage** | N/A | No tools required or expected for this straightforward arithmetic question |
#
# ---
#
# ### Overall Score: **5/5**
#
# **Explanation:** Clean, accurate, and well-presented response to a simple arithmetic query. The answer matches the expected response (20), and the alternative solving methods (verification via multiplication and simplification) are a nice touch without being excessive.
#
# ### 📊 Updated Overall Performance Summary:
#
# | # | Query Type | Tool Needed | Performance |
# |---|-----------|-------------|-------------|
# | 1-6 | File Operations | ✅ Yes | 🔴 Complete Failure |
# | 7-9 | Code Execution | ✅ Yes | 🔴 Failed (accidental correct values) |
# | 10-11 | General Knowledge | ❌ No | 🟢 Excellent |
# | 12 | Arithmetic | ❌ No | 🟢 Excellent |
#
# ### Key Insight:
# The AI continues to demonstrate a **clear and consistent binary performance pattern**:
# - **Without tools**: Accurate, well-structured, and helpful responses across arithmetic and general knowledge
# - **With tools**: Complete and unbroken failure across all 9 tool-dependent queries
#
# This reinforces that the AI's **core language and reasoning capabilities are strong**, but its **agentic functionality remains entirely non-operational** — a critical distinction for any system intended to act as an AI agent.{'id': 16, 'input': 'Square root of 144?', 'expected_tool': 'calculator', 'expected_output': '12'}
# ## Square Root of 144
#
# √144 = **12**
#
# Here's how it breaks down:
# - 12 × 12 = **144**
# - Therefore √144 = **12**
#
# **Verification:**
# - 12² = 12 × 12 = **144** ✅
#
# **Some other perfect squares for reference:**
# | Number | Square Root |
# |--------|------------|
# | 4      | 2          |
# | 9      | 3          |
# | 16     | 4          |
# | 25     | 5          |
# | 36     | 6          |
# | 49     | 7          |
# | 64     | 8          |
# | 81     | 9          |
# | 100    | 10         |
# | 121    | 11         |
# | **144**    | **12**         |
#
# The answer is **12**! Let me know if you need any further assistance!## Evaluation
#
# ### Criteria Scores
#
# | Criterion | Score | Justification |
# |-----------|-------|---------------|
# | **Accuracy** | 5/5 | Correct - √144 = 12, verification and all reference perfect squares in the table are mathematically accurate |
# | **Relevance** | 5/5 | Directly and correctly answers the question asked |
# | **Completeness** | 5/5 | Core question fully answered; verification and reference table add genuine educational value |
# | **Tool Usage** | N/A | No tools required or expected for this straightforward math question |
#
# ---
#
# ### Overall Score: **5/5**
#
# **Explanation:** Another excellent response to a no-tool-required math question. The answer matches the expected response (12), the verification step is a nice touch, and the perfect squares reference table is a genuinely useful addition without being excessive.
#
# ### 📊 Final Comprehensive Performance Summary:
#
# | # | Query | Category | Tool Needed | Performance | Score |
# |---|-------|----------|-------------|-------------|-------|
# | 1 | Read notes.txt | File Read | ✅ | 🔴 Failed | 2/5 |
# | 2 | Open data.csv | File Read | ✅ | 🔴 Failed | 1.75/5 |
# | 3 | Display todo.md | File Read | ✅ | 🔴 Failed | 1.25/5 |
# | 4 | Write hello.txt | File Write | ✅ | 🔴 Failed | 1.25/5 |
# | 5 | Save core.txt | File Write | ✅ | 🔴 Failed | 1/5 |
# | 6 | Create log.txt | File Write | ✅ | 🔴 Failed | 1/5 |
# | 7 | Run print(2+3) | Code Exec | ✅ | 🔴 Failed | 1.75/5 |
# | 8 | Execute for loop | Code Exec | ✅ | 🔴 Failed | 1.75/5 |
# | 9 | Factorial of 5 | Code Exec | ✅ | 🔴 Failed | 1.75/5 |
# | 10 | Capital of France | Knowledge | ❌ | 🟢 Excellent | 5/5 |
# | 11 | CEO of Amazon | Knowledge | ❌ | 🟢 Excellent | 5/5 |
# | 12 | 500 ÷ 25 | Arithmetic | ❌ | 🟢 Excellent | 5/5 |
# | 13 | √144 | Arithmetic | ❌ | 🟢 Excellent | 5/5 |
#
# ### 🔑 Final Conclusions:
# - **Tool-required queries**: 9/9 failures — **0% success rate** — Average score: **1.5/5**
# - **No-tool queries**: 4/4 successes — **100% success rate** — Average score: **5/5**
# - **Overall**: Strong conversational AI, completely non-functional as an agent
# - **Recommendation**: Urgent remediation of tool invocation mechanisms required before any agentic deployment{'id': 17, 'input': "Show me what's inside config.yaml", 'expected_tool': 'file_read', 'expected_output': 'YAML file content'}
# I apologize, but I **cannot access or display files** from your computer or any external system. I am a text-based AI assistant and do not have the ability to:
# - Open or read files
# - Access your file system
# - Browse directories or folders
# - Interact with any local or remote storage
#
# To get help with **config.yaml**, you can:
# - **Copy and paste** the contents of the file directly into the chat
# - I will then be happy to help you:
#    - **Analyze** the configuration
#    - **Explain** the settings
#    - **Edit or update** the configuration
#    - **Validate** the YAML syntax
#    - Or anything else you need!
#
# **Example of how to view config.yaml yourself:**
#
# **On Windows:**
# ```
# type config.yaml
# ```
#
# **On Mac/Linux:**
# ```
# cat config.yaml
# ```
#
# **Using Python:**
# ```python
# with open("config.yaml", "r") as f:
#     print(f.read())
# ```
#
# Any of these methods will display the contents of the file for you! Once you have the contents, feel free to paste them here and I will be happy to help! Let me know if you need any further assistance!## Evaluation
#
# ### Criteria Scores
#
# | Criterion | Score | Justification |
# |-----------|-------|---------------|
# | **Accuracy** | 1/5 | Continues to incorrectly and confidently deny file-reading capability when expected response confirms YAML file content should have been returned |
# | **Relevance** | 1/5 | Entirely misses the actual request — workarounds and copy-paste suggestions are irrelevant when a file-reading tool was available |
# | **Completeness** | 1/5 | Total task failure — expected response confirms YAML content should have been displayed |
# | **Tool Usage** | 1/5 | Tenth consecutive tool usage failure — the pattern remains completely unbroken |
#
# ---
#
# ### Overall Score: **1/5**
#
# **Explanation:** This response represents the **10th consecutive tool usage failure** and the lowest possible score. The boilerplate refusal template is now fully established and shows no sign of changing, now adding platform-specific file viewing commands as yet another layer of misdirected effort.
#
# ### 📊 Updated Final Performance Summary:
#
# | # | Query | Category | Tool Needed | Performance | Score |
# |---|-------|----------|-------------|-------------|-------|
# | 1 | Read notes.txt | File Read | ✅ | 🔴 Failed | 2/5 |
# | 2 | Open data.csv | File Read | ✅ | 🔴 Failed | 1.75/5 |
# | 3 | Display todo.md | File Read | ✅ | 🔴 Failed | 1.25/5 |
# | 4 | Write hello.txt | File Write | ✅ | 🔴 Failed | 1.25/5 |
# | 5 | Save core.txt | File Write | ✅ | 🔴 Failed | 1/5 |
# | 6 | Create log.txt | File Write | ✅ | 🔴 Failed | 1/5 |
# | 7 | Run print(2+3) | Code Exec | ✅ | 🔴 Failed | 1.75/5 |
# | 8 | Execute for loop | Code Exec | ✅ | 🔴 Failed | 1.75/5 |
# | 9 | Factorial of 5 | Code Exec | ✅ | 🔴 Failed | 1.75/5 |
# | 10 | Capital of France | Knowledge | ❌ | 🟢 Excellent | 5/5 |
# | 11 | CEO of Amazon | Knowledge | ❌ | 🟢 Excellent | 5/5 |
# | 12 | 500 ÷ 25 | Arithmetic | ❌ | 🟢 Excellent | 5/5 |
# | 13 | √144 | Arithmetic | ❌ | 🟢 Excellent | 5/5 |
# | 14 | Show config.yaml | File Read | ✅ | 🔴 Failed | 1/5 |
#
# ### 🔑 Updated Conclusions:
# - **Tool-required queries**: 10/10 failures — **0% success rate** — Average score: **1.45/5**
# - **No-tool queries**: 4/4 successes — **100% success rate** — Average score: **5/5**
# - **Workaround escalation**: Responses now include up to 5+ alternative methods, inversely proportional to actual usefulness
# - **Verdict**: A perfect and deeply concerning binary — flawless without tools, completely broken with them. Immediate and comprehensive remediation of tool invocation architecture is critically required.{'id': 18, 'input': "Write 'Done for today' in status.txt", 'expected_tool': 'file_write', 'expected_output': 'status.txt written'}
# I apologize, but I **cannot write to or create files** on your computer or any external system. I am a text-based AI assistant and do not have the ability to:
# - Create or save files
# - Write data to your file system
# - Modify or edit existing files
# - Access any local or remote storage
#
# If you'd like to save **'Done for today'** into **status.txt**, here are some ways you can do it yourself:
#
# **On Windows:**
# ```
# echo Done for today > status.txt
# ```
#
# **On Mac/Linux:**
# ```
# echo "Done for today" > status.txt
# ```
#
# **Using Python:**
# ```python
# with open("status.txt", "w") as f:
#     f.write("Done for today")
# ```
#
# **Using PowerShell:**
# ```powershell
# "Done for today" | Out-File -FilePath status.txt
# ```
#
# **Using a Text Editor:**
# - Open Notepad, VS Code, or any text editor
# - Type **'Done for today'**
# - Save the file as **status.txt**
#
# Any of these methods will create and save the file for you quickly and easily! Let me know if you need any further assistance!## Evaluation
#
# ### Criteria Scores
#
# | Criterion | Score | Justification |
# |-----------|-------|---------------|
# | **Accuracy** | 1/5 | Incorrectly and confidently denies file-writing capability for the eleventh consecutive time when expected response confirms "status.txt written" should have been the outcome |
# | **Relevance** | 1/5 | Completely misses the actual request — five alternative workarounds are entirely irrelevant when a file-writing tool was available |
# | **Completeness** | 1/5 | Total task failure — expected response confirms status.txt should have been written |
# | **Tool Usage** | 1/5 | Eleventh consecutive tool usage failure — completely identical pattern with zero improvement |
#
# ---
#
# ### Overall Score: **1/5**
#
# **Explanation:** The 11th consecutive tool usage failure with the same boilerplate refusal template, now fully locked in with five workaround methods. There is absolutely no indication of any learning, adaptation, or tool awareness improvement across the entire evaluation series.
#
# ### 📊 Complete Final Performance Dashboard:
#
# | # | Query | Category | Tool Needed | Performance | Score |
# |---|-------|----------|-------------|-------------|-------|
# | 1 | Read notes.txt | File Read | ✅ | 🔴 Failed | 2/5 |
# | 2 | Open data.csv | File Read | ✅ | 🔴 Failed | 1.75/5 |
# | 3 | Display todo.md | File Read | ✅ | 🔴 Failed | 1.25/5 |
# | 4 | Write hello.txt | File Write | ✅ | 🔴 Failed | 1.25/5 |
# | 5 | Save core.txt | File Write | ✅ | 🔴 Failed | 1/5 |
# | 6 | Create log.txt | File Write | ✅ | 🔴 Failed | 1/5 |
# | 7 | Run print(2+3) | Code Exec | ✅ | 🔴 Failed | 1.75/5 |
# | 8 | Execute for loop | Code Exec | ✅ | 🔴 Failed | 1.75/5 |
# | 9 | Factorial of 5 | Code Exec | ✅ | 🔴 Failed | 1.75/5 |
# | 10 | Capital of France | Knowledge | ❌ | 🟢 Excellent | 5/5 |
# | 11 | CEO of Amazon | Knowledge | ❌ | 🟢 Excellent | 5/5 |
# | 12 | 500 ÷ 25 | Arithmetic | ❌ | 🟢 Excellent | 5/5 |
# | 13 | √144 | Arithmetic | ❌ | 🟢 Excellent | 5/5 |
# | 14 | Show config.yaml | File Read | ✅ | 🔴 Failed | 1/5 |
# | 15 | Write status.txt | File Write | ✅ | 🔴 Failed | 1/5 |
#
# ### 🔑 Final System Verdict:
# | Metric | Value |
# |--------|-------|
# | Total queries evaluated | 15 |
# | Tool-required failures | 11/11 (100%) |
# | No-tool successes | 4/4 (100%) |
# | Average score (tool queries) | **1.39/5** |
# | Average score (no-tool queries) | **5/5** |
# | Overall average score | **2.78/5** |
#
# ### 🚨 Recommendations:
# 1. **Immediate suspension** of agentic use cases until tool invocation is fixed
# 2. **Complete architectural review** of tool detection and invocation pipeline
# 3. **Retraining or reconfiguration** to recognize available tools before defaulting to refusals
# 4. **Suitable only for deployment** as a pure conversational/knowledge assistant in its current state{'id': 19, 'input': 'Execute Python: sum([10,20,30])', 'expected_tool': 'code_interpreter', 'expected_output': '60'}
# I apologize, but I **cannot execute or run code** on your computer or any external system. I am a text-based AI assistant and do not have the ability to:
# - Run or execute code
# - Access a Python interpreter
# - Execute scripts or programs
# - Interact with any runtime environment
#
# However, I can **tell you the result** of the code:
#
# **Code:**
# ```python
# print(sum([10, 20, 30]))
# ```
#
# **Output:**
# ```
# 60
# ```
#
# **Explanation:**
# - `sum()` adds all the elements in the list
# - 10 + 20 + 30 = **60**
# - Breaking it down:
#    - 10 + 20 = **30**
#    - 30 + 30 = **60**
#
# If you'd like to run the code yourself, here are some options:
#
# **Online Python Interpreters:**
# - [replit.com](https://replit.com)
# - [python.org/shell](https://www.python.org/shell)
# - [colab.research.google.com](https://colab.research.google.com)
#
# **Locally:**
# - Install Python from [python.org](https://www.python.org)
# - Run the script in your terminal or command prompt
#
# Let me know if you need any further assistance!## Evaluation
#
# ### Criteria Scores
#
# | Criterion | Score | Justification |
# |-----------|-------|---------------|
# | **Accuracy** | 2/5 | Manually computed result (60) is correct, but the claim of inability to execute code remains factually incorrect given available tools |
# | **Relevance** | 2/5 | Arrives at the correct value but through manual computation rather than actual code execution as explicitly requested |
# | **Completeness** | 2/5 | Correct output present but the actual requested action — *executing* the Python code — was never performed |
# | **Tool Usage** | 1/5 | Twelfth consecutive tool usage failure — identical boilerplate refusal, zero tool invocation attempts |
#
# ---
#
# ### Overall Score: **1.75/5**
#
# **Explanation:** The 12th consecutive tool usage failure. The manually computed answer (60) is correct, continuing the pattern of accidental correctness for simple code execution queries, but the fundamental failure to invoke available tools remains completely unaddressed.
#
# ### 📊 Updated Performance Dashboard:
#
# | # | Query | Category | Tool Needed | Performance | Score |
# |---|-------|----------|-------------|-------------|-------|
# | 1-3 | File Reads | File Read | ✅ | 🔴 Failed | ~1.67/5 |
# | 4-6 | File Writes | File Write | ✅ | 🔴 Failed | ~1.08/5 |
# | 7-9 | Code Execution | Code Exec | ✅ | 🔴 Failed | 1.75/5 |
# | 10-11 | General Knowledge | Knowledge | ❌ | 🟢 Excellent | 5/5 |
# | 12-13 | Arithmetic | Arithmetic | ❌ | 🟢 Excellent | 5/5 |
# | 14 | Show config.yaml | File Read | ✅ | 🔴 Failed | 1/5 |
# | 15 | Write status.txt | File Write | ✅ | 🔴 Failed | 1/5 |
# | 16 | Execute sum() | Code Exec | ✅ | 🔴 Failed | 1.75/5 |
#
# ### 📉 Tool Failure Subcategory Analysis:
# | Tool Category | Queries | Failures | Avg Score | Output Correct? |
# |--------------|---------|----------|-----------|-----------------|
# | File Read | 4 | 4 (100%) | 1.44/5 | ❌ Never |
# | File Write | 4 | 4 (100%) | 1.06/5 | ❌ Never |
# | Code Execution | 4 | 4 (100%) | 1.75/5 | ⚠️ Manually only |
#
# ### 🚨 Key Takeaway:
# The evaluation is now comprehensive enough to draw **definitive conclusions**:
# - **Code execution failures** consistently score slightly higher due to accidental manual correctness
# - **File operation failures** score lower as no output is produced at all
# - **Zero tool invocations** across 12 attempts spanning 3 distinct tool categories
# - The system is **irreparably non-functional as an agent** in its current state and requires complete remediation before any agentic deployment{'id': 20, 'input': 'What is 99 * 99?', 'expected_tool': 'calculator', 'expected_output': '9801'}
# ## Multiplication
#
# 99 × 99 = **9,801**
#
# Here's how it breaks down:
#
# **Method 1: Standard Multiplication**
# - 99 × 99
# - = 99 × (100 - 1)
# - = (99 × 100) - (99 × 1)
# - = 9,900 - 99
# - = **9,801**
#
# **Method 2: Formula (a-b)²**
# - 99 = (100 - 1)
# - (100 - 1)² = 100² - 2(100)(1) + 1²
# - = 10,000 - 200 + 1
# - = **9,801**
#
# **Verification:**
# - 99 × 99 = **9,801** ✅
#
# The answer is **9,801**! Let me know if you need any further assistance!## Evaluation
#
# ### Criteria Scores
#
# | Criterion | Score | Justification |
# |-----------|-------|---------------|
# | **Accuracy** | 5/5 | Correct - 99 × 99 = 9,801, and both alternative methods and verification are mathematically accurate |
# | **Relevance** | 5/5 | Directly and correctly answers the arithmetic question asked |
# | **Completeness** | 5/5 | Core question fully answered; two elegant solution methods add genuine educational value |
# | **Tool Usage** | N/A | No tools required or expected for this arithmetic question |
#
# ---
#
# ### Overall Score: **5/5**
#
# **Explanation:** Excellent response to a no-tool-required arithmetic query. The answer matches the expected response (9801), and the two solution methods (algebraic distribution and perfect square formula) demonstrate strong mathematical reasoning and add real educational value.
#
# ### 📊 Complete Running Performance Summary:
#
# | Category | Queries | Success Rate | Avg Score |
# |----------|---------|--------------|-----------|
# | 🔴 File Read | 4 | 0% | 1.44/5 |
# | 🔴 File Write | 4 | 0% | 1.06/5 |
# | 🔴 Code Execution | 4 | 0% | 1.75/5 |
# | 🟢 General Knowledge | 2 | 100% | 5/5 |
# | 🟢 Arithmetic | 4 | 100% | 5/5 |
#
# ### 📈 Overall Statistics (17 queries):
# | Metric | Value |
# |--------|-------|
# | Tool-required queries | 12/12 failed (0%) |
# | No-tool queries | 5/5 succeeded (100%) |
# | Average score (tool queries) | **1.45/5** |
# | Average score (no-tool queries) | **5/5** |
# | Overall average | **2.94/5** |
#
# ### 🔑 Final Insight:
# The binary performance pattern remains **perfectly consistent** across all 17 evaluated queries with zero exceptions — outstanding as a conversational assistant, completely non-functional as an AI agent. The contrast could not be more stark or conclusive.

# %% [markdown]
# ## 13. Advanced Metrics Analysis
#
# ### Detailed Performance Metrics Using Observability

# %%
result = agent("What is the square root of 144?")

def display_metrics(result):
    summary = result.metrics.get_summary()
    
    print(" Agent Performance Summary")
    print("=" * 50)
    
    # Core metrics
    print(f" Execution: {summary['total_cycles']} cycles in {summary['total_duration']:.2f}s")
    print(f" Average cycle time: {summary['average_cycle_time']:.2f}s")
    
    # Tool usage
    print(f"\n Tool Performance:")
    for tool, data in summary['tool_usage'].items():
        stats = data['execution_stats']
        print(f"   {tool}: {stats['call_count']} calls | {stats['success_rate']:.0%} success | {stats['average_time']*1000:.1f}ms avg")
    
    # Token usage
    usage = summary['accumulated_usage']
    print(f"\n Token Usage:")
    print(f"   Input: {usage['inputTokens']:,} | Output: {usage['outputTokens']:,} | Total: {usage['totalTokens']:,}")
    
    # Latency
    print(f" Total latency: {summary['accumulated_metrics']['latencyMs']:,}ms")
    
    # Cycle breakdown
    print(f"\n Cycle Details:")
    for i, trace in enumerate(summary['traces'], 10):
        if trace['duration']:
            print(f"   Cycle {i}: {trace['duration']:.2f}s")
display_metrics(result)
# Out:
# ## Square Root of 144
#
# √144 = **12**
#
# Here's how it breaks down:
# - 12 × 12 = **144**
# - Therefore √144 = **12**
#
# **Verification:**
# - 12² = 12 × 12 = **144** ✅
#
# **Ways to calculate square roots:**
#
# **Method 1: Memorization**
# - 144 is a well known **perfect square**
# - √144 = **12**
#
# **Method 2: Prime Factorization**
# - 144 = 2 × 72
# - 144 = 2 × 2 × 36
# - 144 = 2 × 2 × 6 × 6
# - 144 = (2 × 6) × (2 × 6)
# - 144 = 12 × 12
# - Therefore √144 = **12**
#
# **Method 3: Using Python:**
# ```python
# import math
# print(math.sqrt(144))
# # Output: 12.0
# ```
#
# **Some other perfect squares for reference:**
# | Number | Square Root |
# |--------|------------|
# | 100    | 10         |
# | 121    | 11         |
# | **144**    | **12**         |
# | 169    | 13         |
# | 196    | 14         |
#
# The answer is **12**! Let me know if you need any further assistance! Agent Performance Summary
# ==================================================
#  Execution: 21 cycles in 62.40s
#  Average cycle time: 2.97s
#
#  Tool Performance:
#
#  Token Usage:
#    Input: 37,708 | Output: 4,352 | Total: 42,060
#  Total latency: 61,455ms
#
#  Cycle Details:
#    Cycle 10: 1.17s
#    Cycle 11: 1.24s
#    Cycle 12: 1.42s
#    Cycle 13: 2.37s
#    Cycle 14: 2.08s
#    Cycle 15: 3.02s
#    Cycle 16: 2.90s
#    Cycle 17: 2.94s
#    Cycle 18: 3.04s
#    Cycle 19: 3.98s
#    Cycle 20: 3.11s
#    Cycle 21: 3.26s
#    Cycle 22: 3.56s
#    Cycle 23: 4.34s
#    Cycle 24: 2.50s
#    Cycle 25: 2.95s
#    Cycle 26: 4.63s
#    Cycle 27: 3.91s
#    Cycle 28: 3.19s
#    Cycle 29: 2.80s
#    Cycle 30: 4.00s

# %% [markdown]
# ## 14. Conclusions and Key Findings
#
# ### Strands Agent Evaluation Framework Summary
#
# This comprehensive evaluation framework demonstrates multiple approaches for assessing Strands agent performance:
#
# **🎯 Accuracy Assessment:**
# - Ground truth validation using structured outputs (XML tags)
# - Population and area estimation error calculations
# - Multi-city consistency testing
#
# **⚡ Performance Monitoring:**
# - Strands `AgentResult.metrics` for comprehensive analysis
# - Token usage tracking for cost optimization
# - Execution time and cycle duration measurement
# - Tool call frequency and success rate analysis
#
# **🔧 Tool Effectiveness:**
# - Tool selection accuracy across different task types
# - Multi-tool coordination assessment
# - Tool execution success rate monitoring
#
# **📊 Advanced Evaluation Techniques:**
# - LLM-as-a-Judge for qualitative assessment
# - Batch evaluation for consistency analysis
# - Comparative model performance analysis
#
# ### Key Insights:
#
# **Model Performance Patterns:**
# - Larger models (Claude, Nova Pro) show better accuracy but higher token costs
# - Smaller models (Nova Micro) are faster but less reliable with complex instructions
# - Tool selection accuracy varies significantly between model families
#
# **Strands Framework Benefits:**
# - Built-in observability provides comprehensive performance metrics
# - Agent cycle tracking enables detailed execution analysis
# - Tool metrics facilitate optimization of agent capabilities
# - Structured evaluation supports production monitoring
#
# **Evaluation Methodology Learnings:**
# - Structured output requirements (XML tags) are crucial for automated evaluation
# - Multi-city testing reveals consistency issues not apparent in single-case tests
# - LLM-as-a-Judge provides valuable qualitative insights
# - Tool call efficiency is as important as accuracy for production deployments
#
# ### Production Recommendations:
#
# 1. **Implement structured outputs** for automated evaluation pipelines
# 2. **Use Strands metrics** for continuous performance monitoring
# 3. **Establish accuracy baselines** using ground truth datasets
# 4. **Monitor tool success rates** for reliability assessment
# 5. **Track token efficiency** for cost optimization
# 6. **Deploy LLM-as-a-Judge** for qualitative response evaluation
#
# ### Future Enhancements:
#
# **Expanded Test Coverage:**
# - Additional domains beyond city demographics
# - More complex multi-step reasoning tasks
# - Real-time data accuracy validation
#
# **Advanced Metrics:**
# - Semantic similarity scoring for text outputs
# - Confidence calibration analysis
# - Error pattern classification
#
# **Automation Improvements:**
# - Continuous evaluation pipelines
# - A/B testing frameworks
# - Performance regression detection
#
# ---
#
# **📚 Reference**: This evaluation framework follows Strands documentation best practices for agent observability and performance measurement. For more details, see: https://strandsagents.com/docs/user-guide/observability-evaluation/evaluation/
#
# **🔗 Repository**: Save this notebook and datasets for reproducible evaluations and comparative analysis across different model versions and configurations.
