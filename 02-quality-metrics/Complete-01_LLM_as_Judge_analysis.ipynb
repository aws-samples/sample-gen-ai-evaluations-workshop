# %% [markdown]
# # Model Quality Metrics
#
# ## Overview
# This notebook demonstrates advanced evaluation metrics for US cities demographic analysis using LLM-as-a-Judge methodology.
#
# ## What We'll Cover
# 1. **Programmatic Testing** - Verify model accuracy against ground truth city data
# 2. **LLM as a Judge** - Assess response quality, accuracy, and analytical depth
# 3. **Evaluation Analysis** - Compare performance across question types and complexity levels
# 4. **Results Visualization** - Present findings and recommendations
#
# ## Prerequisites
# - AWS account with Bedrock access
# - Python 3.10+
# - boto3 library

# %% [markdown]
# ## Setup and Dependencies

# %%
import pandas as pd
import json
from time import sleep

# Import our modular utility functions
from utils import *

# Configuration Parameters
DATA_PATH = "./city_pop.csv"
SHOW_DETAILED_RESULTS = True 
SCALE_TEST_SAMPLES = 1000  # Number of samples for scale testing
RANDOM_SEED = 42  # For reproducibility
SHOW_PLOTS = True  # Display visualization


print("Utility modules loaded")
# Out:
# Utility modules loaded

# %% [markdown]
# ## 1. Load the dataset
#
# We will be using the US Cities Population Dataset which contains comprehensive demographic and geographic information for the top 314 most populous cities in the United States. This dataset provides a detailed snapshot of American urban demographics, featuring cities with populations ranging from over 8.4 million (New York City) down to approximately 100,000 residents (Sunrise, FL).
#
# **Dataset features:**
# - **city**: Name of the city
# - **state**: Two-letter state abbreviation
# - **population**: Current population count (formatted with commas as strings)
# - **land_area_mi2**: Land area in square miles
#
# **Dataset characteristics:**
# - **Size**: 314 cities across all 50 US states plus Washington DC
# - **Population range**: 8,478,072 (New York) to 100,128 (Sunrise, FL)
# - **Geographic coverage**: Represents major metropolitan areas nationwide
# - **Data quality**: Some entries contain footnote references that may need cleaning
#
# This comprehensive dataset is ideal for analyzing urban demographics, population density patterns, regional growth trends, and the geographic distribution of America's largest cities. The inclusion of both population and land area data enables calculations of population density and comparative urban planning analysis.

# %%
df = pd.read_csv(DATA_PATH)
print(f"Dataset loaded: {df.shape[0]} cities, {df.shape[1]} features")
print(f"Features available: {list(df.columns)}")

# Display sample data for context
print("\n Sample city records:")
for i in range(min(3, len(df))):
    print(f"\n--- City {i+1} ---")
    print(f"City: {df.iloc[i]['city']}")
    print(f"State: {df.iloc[i]['state']}")
    print(f"Population: {df.iloc[i]['population']}")
    print(f"Land Area: {df.iloc[i]['land_area_mi2']} sq mi")
# Out:
# Dataset loaded: 346 cities, 4 features
# Features available: ['city', 'state', 'population', 'land_area_mi2']
#
#  Sample city records:
#
# --- City 1 ---
# City: New York[c]
# State: NY
# Population: 8,478,072
# Land Area: 300.5 sq mi
#
# --- City 2 ---
# City: Los Angeles
# State: CA
# Population: 3,878,704
# Land Area: 469.5 sq mi
#
# --- City 3 ---
# City: Chicago
# State: IL
# Population: 2,721,308
# Land Area: 227.7 sq mi

# %% [markdown]
# ## 2. Programmatic Model Testing
#
# Now, we will perform programmatic testing on our dataset. We will ask the model a series of questions about specific cities and verify whether the model's responses match the data we have in our dataset. This approach allows us to systematically evaluate the model's accuracy against our ground truth data.

# %%
# Define comprehensive test questions
test_questions = [
    "What is the land area of of New York?",
    "What is the land area of Los Angeles in square miles?", 
    "What is the population of Chicago?",
    "What is the land area of Houston?",
    "Which city has a larger population: Phoenix or New York?",
    "What is the land area of San Francisco?",
    "What is the population of Seattle?",
    "What is the total land area of Boston?",
    "What is the land area of Las Vegas?"
] # Use configured number of questions

print(f"Prepared {len(test_questions)} test questions")
print("\nQuestion Types:")
print("• Direct factual lookups")
print("• Comparative queries")
print("• Numerical data retrieval")
# Out:
# Prepared 9 test questions
#
# Question Types:
# • Direct factual lookups
# • Comparative queries
# • Numerical data retrieval

# %%
# Run programmatic tests with progress tracking
print("Running Programmatic Tests...\n")
test_results = run_programmatic_tests(test_questions, df)
# Out:
# Running Programmatic Tests...
#
# Testing model responses against ground truth dataset
# Testing 1/9: What is the land area of of New York?
# Testing 2/9: What is the land area of Los Angeles in square miles?
# Testing 3/9: What is the population of Chicago?
# Testing 4/9: What is the land area of Houston?
# Testing 5/9: Which city has a larger population: Phoenix or New York?
# Testing 6/9: What is the land area of San Francisco?
# Testing 7/9: What is the population of Seattle?
# Testing 8/9: What is the total land area of Boston?
# Testing 9/9: What is the land area of Las Vegas?
# PROGRAMMATIC TEST RESULTS:
# Passed: 3/9
# Success Rate: 33.33%
#
#  Detailed Results:
# ❌ FAIL - What is the land area of of New York?
#    Response: {
#   "answer": 302.6,
#   "city": "New York",
#   "metric": "land_area_mi2"
# }
# ❌ FAIL - What is the land area of Los Angeles in square miles?
#    Response: {
#   "answer": 502.7,
#   "city": "Los Angeles",
#   "metric": "land_area_mi2"
# }
# ❌ FAIL - What is the population of Chicago?
#    Response: {
#   "answer": 2746388,
#   "city": "Chicago",
#   "metric": "population"
# }
# ❌ FAIL - What is the land area of Houston?
#    Response: {
#   "answer": 670.2,
#   "city": "Houston",
#   "metric": "land_area_mi2"
# }
# ✅ PASS - Which city has a larger population: Phoenix or New York?
#    Response: {
#   "answer": 8336817,
#   "city": "New York",
#   "metric": "population",
#   "comparison": true
# }
# ✅ PASS - What is the land area of San Francisco?
#    Response: {
#   "answer": 46.9,
#   "city": "San Francisco",
#   "metric": "land_area_mi2"
# }
# ❌ FAIL - What is the population of Seattle?
#    Response: {
#   "answer": 749256,
#   "city": "Seattle",
#   "metric": "population"
# }
# ✅ PASS - What is the total land area of Boston?
#    Response: {
#   "answer": 48.3,
#   "city": "Boston",
#   "metric": "land_area_mi2"
# }
# ❌ FAIL - What is the land area of Las Vegas?
#    Response: {
#   "answer": 135.86,
#   "city": "Las Vegas",
#   "metric": "land_area_mi2"
# }

# %%
# Analyze test results
passed = sum(1 for r in test_results if r['passed'])
failed = len(test_results) - passed

# Visual result summary
print("\n" + "="*50)
print(" PROGRAMMATIC TEST RESULTS")
print("="*50)

# Create visual pass/fail bar
total = len(test_results)
bar_length = 30
passed_length = int(bar_length * passed / total)
bar = "█" * passed_length + "░" * (bar_length - passed_length)

print(f"\nSuccess Rate: [{bar}] {(passed/total)*100:.1f}%")
print(f"\n✅ Passed: {passed}")
print(f"❌ Failed: {failed}")
print(f"Total: {total}")
# Out:
# ==================================================
#  PROGRAMMATIC TEST RESULTS
# ==================================================
#
# Success Rate: [██████████░░░░░░░░░░░░░░░░░░░░] 33.3%
#
# ✅ Passed: 3
# ❌ Failed: 6
# Total: 9

# %% [markdown]
# ### **Transition: Why Context Matters**
#
# The programmatic tests reveal a common challenge: **LLMs struggle with precise numerical facts without context**.
#
# This happens because:
# - Training data contains conflicting or outdated information
# - Numbers are particularly challenging for token-based models
# - Geographic data changes over time
#
# **Solution**: Use **Retrieval-Augmented Generation (RAG)** to provide accurate context.
#
# Let's see how adding context improves performance

# %% [markdown]
# ---
# ## 3. Enhanced Evaluation with Context (RAG)
#
# Now we'll provide the model with relevant context and see how it impacts response quality.

# %%
cities_questions = [
    {
        'question': 'What is the population of New York City?',
        'context': 'New York[c], NY: population=8,478,072, land_area_mi2=300.5'
    },
    {
        'question': 'Which city has a larger population: Los Angeles or Chicago?',
        'context': 'Los Angeles, CA: population=3,878,704, land_area_mi2=469.5\nChicago, IL: population=2,721,308, land_area_mi2=227.7'
    },
    {
        'question': 'What is the population density of San Francisco?',
        'context': 'San Francisco, CA: population=815,201, land_area_mi2=46.9'
    },
    {
        'question': 'What is the land area of Houston in square miles?',
        'context': 'Houston, TX: population=2,304,580, land_area_mi2=670.2'
    },
    {
        'question': 'List the top 3 most populous cities in the United States.',
        'context': 'Top cities: New York (8,478,072), Los Angeles (3,878,704), Chicago (2,721,308)'
    },
    {
        'question': 'Calculate the population density of Chicago.',
        'context': 'Chicago, IL: population=2,721,308, land_area_mi2=227.7'
    }
]

print(" Using RAG approach with dataset context for grounding")

print(f"Prepared {len(cities_questions)} contextual questions")
print("\nQuestion complexity levels:")
print("• Basic: Direct retrieval")
print("• Intermediate: Comparisons")
print("• Advanced: Calculations")
# Out:
#  Using RAG approach with dataset context for grounding
# Prepared 6 contextual questions
#
# Question complexity levels:
# • Basic: Direct retrieval
# • Intermediate: Comparisons
# • Advanced: Calculations

# %%
cities_responses = []
for i, item in enumerate(cities_questions):
    print(f" Processing {i+1}/{len(cities_questions)}: {item['question']}")
    
    # The utility function handles Bedrock API calls and response formatting
    model_response = generate_model_response(item['question'], item['context'])
    
    cities_responses.append({
        'question': item['question'],
        'model_response': model_response,
        'context': item['context']
    })
    
    sleep(1)  # Rate limiting

print(f"\nGenerated {len(cities_responses)} contextual responses for evaluation")

# Display sample responses
print("\nSample generated responses:")
for i, response in enumerate(cities_responses[:2]):
    print(f"\n--- Response {i+1} ---")
    print(f"Question: {response['question']}")
    print(f"Model Response: {response['model_response'][:200]}...")
    print("-" * 50)
# Out:
#  Processing 1/6: What is the population of New York City?
#  Processing 2/6: Which city has a larger population: Los Angeles or Chicago?
#  Processing 3/6: What is the population density of San Francisco?
#  Processing 4/6: What is the land area of Houston in square miles?
#  Processing 5/6: List the top 3 most populous cities in the United States.
#  Processing 6/6: Calculate the population density of Chicago.
# Generated 6 contextual responses for evaluation
#
# Sample generated responses:
#
# --- Response 1 ---
# Question: What is the population of New York City?
# Model Response: According to the provided data, New York City has a population of 8,478,072 people. This makes it the most populous city in the United States....
# --------------------------------------------------
#
# --- Response 2 ---
# Question: Which city has a larger population: Los Angeles or Chicago?
# Model Response: Based on the provided context data, Los Angeles has a larger population than Chicago. Los Angeles has a population of 3,878,704 people, while Chicago has a population of 2,721,308 people. The differen...
# --------------------------------------------------

# %% [markdown]
# ### **Key Insight**
#
# > **The Power of Context**: By providing relevant context, we ground the model's responses in accurate data. But how do we evaluate the quality of these responses at scale? Enter LLM-as-a-Judge...

# %% [markdown]
# ---
# ## 4. LLM as A Judge Evaluation
#
# LLM-as-a-Judge is an evaluation methodology where we use LLMs to automatically evaluate and score other AI model outputs. Instead of relying on human evaluators, we prompt LLMs to act as judges, assessing responses based on specific criteria like accuracy, helpfulness, tone, and relevance.
#
# This approach has become increasingly popular because:
# - **Scalability & Cost-effectiveness**: Can evaluate thousands of responses quickly without expensive human bottlenecks
# - **Consistency**: Applies the same evaluation criteria uniformly across all responses
# - **Detailed Feedback**: Can provide structured scoring and reasoning for each assessment

# %%
# Understand the judge evaluation criteria
print("Judge Evaluation Criteria:")
print("=" * 40)
print("1. **Data Accuracy**: Correctness of facts")
print("2. **Calculation Correctness**: Mathematical accuracy")
print("3. **Geographic Knowledge**: Understanding of US geography")
print("4. **Analytical Depth**: Quality of insights")
print("5. **Data Handling**: Proper formatting handling")

print("\nJudge Prompt Preview:")
print(JUDGE_PROMPT_TEMPLATE[:600] + "...")
# Out:
# Judge Evaluation Criteria:
# ========================================
# 1. **Data Accuracy**: Correctness of facts
# 2. **Calculation Correctness**: Mathematical accuracy
# 3. **Geographic Knowledge**: Understanding of US geography
# 4. **Analytical Depth**: Quality of insights
# 5. **Data Handling**: Proper formatting handling
#
# Judge Prompt Preview:
#
# You will be given a question about US cities demographics and population data.
# Your task is to evaluate a model's response for accuracy, completeness, and analytical quality.
#
# Here is the question about US cities:
# <question>{QUESTION}</question>
#
# Here is the model's response:
# <model_response>{MODEL_RESPONSE}</model_response>
#
# Here is the context from the data:
# <dataset>{context}</dataset>
#
# **Dataset Context:** The response should be based on the US Cities Population Dataset containing 314 most populous US cities with the following features:
# - **city**: City name
# - **state**: Two-letter state...

# %%
# Run judge evaluations
print("Running LLM Judge Evaluations...\n")
evaluation_results = run_judge_evaluations(cities_responses)
print("\nJudge evaluations complete!")
# Out:
# Running LLM Judge Evaluations...
#
# Starting LLM-as-a-Judge evaluation...
#  Running parallel evaluations for efficiency..
#  Completed 6 comprehensive evaluations
#
# Judge evaluations complete!

# %% [markdown]
# ## 4. Parse and Analyze Results
#
# Extract structured information from the judge evaluations.

# %%
# Process and analyze results
parsed_evaluations, df_evaluations, metrics = process_evaluation_results(
    cities_responses, evaluation_results
)
# Out:
#  Processing evaluation results and extracting insights.
#
# Evaluation DataFrame created with columns:
# ['question', 'model_response', 'context', 'evaluation_text', 'analysis', 'question_type', 'complexity', 'score', 'reasoning', 'improvements', 'numeric_score']
#
# Evaluation Summary:
# Average Score: 10.00
# Score Range: 10.0 - 10.0
#
# Question Type Distribution:
# question_type
# factual_lookup        2
# ranking_comparison    2
# calculation_based     2
# Name: count, dtype: int64
#
# Complexity Distribution:
# complexity
# Basic    6
# Name: count, dtype: int64

# %% [markdown]
# ---
# ## 5. Comprehensive Results Dashboard

# %%
# Create and display comprehensive evaluation summary
summary = create_evaluation_summary(test_results, df_evaluations)
print_evaluation_dashboard(summary)
# Out:
# ================================================================================
#                          EVALUATION DASHBOARD 📊
# ================================================================================
#
# PROGRAMMATIC TESTING
# ----------------------------------------
# Success Rate: [█████████░░░░░░░░░░░░░░░░░░░░░] 33.3%
# Results: ✅ 3 passed | ❌ 6 failed | Total: 9
#
# LLM JUDGE EVALUATION
# ----------------------------------------
# Average Score: 🟩🟩🟩🟩🟩🟩🟩🟩🟩🟩🟩🟩🟩🟩🟩🟩🟩🟩🟩🟩 10.00/10
# Score Range: 10.0 - 10.0
# Median: 10.0 | Std Dev: 0.00
# Total Evaluated: 6
#
# PERFORMANCE BY QUESTION TYPE
# ----------------------------------------
# Calculation Based         ▰▰▰▰▰▰▰▰▰▰ 10.0/10 (2 samples)
# Factual Lookup            ▰▰▰▰▰▰▰▰▰▰ 10.0/10 (2 samples)
# Ranking Comparison        ▰▰▰▰▰▰▰▰▰▰ 10.0/10 (2 samples)
#
# ================================================================================

# %%
# Save results for future analysis
if 'df_evaluations' in locals() and not df_evaluations.empty:
    json_file, csv_file = save_evaluation_results(parsed_evaluations, "cities_evaluation")
    print("\nResults saved:")
    print(f"  • JSON: {json_file}")
    if csv_file:
        print(f"  • CSV: {csv_file}")
        
        # Display detailed metrics
        if SHOW_DETAILED_RESULTS:
            print("\nDetailed Metrics:")
            metrics_df = display_evaluation_metrics(csv_file)
# Out:
# Results saved:
#   • JSON: cities_evaluation_results.json
#   • CSV: cities_evaluation_summary.csv
#
# Detailed Metrics:
# Loading metrics from: cities_evaluation_summary.csv
#
# CITIES EVALUATION METRICS TABLE (6 records)
# ================================================================================
#                                                       question  numeric_score       question_type complexity                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         analysis                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              reasoning                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     improvements
# 0                     What is the population of New York City?           10.0      factual_lookup      Basic                                                                                                                                                                                                     The model's response is factually accurate. It correctly states that New York City has a population of 8,478,072 people according to the provided dataset. The model also adds contextual information that New York City is the most populous city in the United States, which is correct based on the dataset description stating that the cities range from "8.4M+ (NYC) down to ~100K residents," with NYC being at the top end of that range.\n\nThe response is concise but complete for this straightforward factual question. The model properly handled the population figure without introducing formatting errors.                                                                                                                             The model deserves a perfect score because:\n1. It provided the exact population figure (8,478,072) that matches the dataset.\n2. It correctly identified NYC as the most populous city in the United States, showing awareness of the broader context of the dataset.\n3. The response was appropriately concise for a straightforward factual lookup question.\n4. No calculation was required, and the model didn't introduce any unnecessary or incorrect information.\n5. The model properly handled the population figure without formatting issues.                                                                                                 The response is appropriate for this basic factual lookup question. If one wanted to enhance it slightly, the model could have mentioned the land area provided in the dataset (300.5 square miles) to give a more complete picture of the city's physical size in relation to its large population. However, this wasn't requested in the question, so its absence doesn't constitute an error.
# 1  Which city has a larger population: Los Angeles or Chicago?           10.0  ranking_comparison      Basic  The model's response is factually accurate and directly answers the question. It correctly identifies that Los Angeles has a larger population than Chicago based on the provided dataset context. The response includes the exact population figures for both cities (Los Angeles: 3,878,704 and Chicago: 2,721,308) and calculates the difference between them (1,157,396), which is mathematically correct. The model provides a clear comparison statement that Los Angeles is "significantly more populous" than Chicago, which is an appropriate characterization given the substantial difference in population.\n\nThe response is concise but complete for this straightforward comparison question. It doesn't include unnecessary information and focuses precisely on the population comparison that was requested.          The model deserves a perfect score because:\n1. It correctly identified the larger city (Los Angeles) based on population\n2. It accurately cited the population figures from the dataset (3,878,704 vs 2,721,308)\n3. It calculated the exact difference between the populations (1,157,396)\n4. It provided an appropriate qualitative assessment ("significantly more populous")\n5. It stayed focused on the question without adding irrelevant information\n6. It properly handled the numeric data without formatting issues\n\nThe response is straightforward but complete for this basic comparison question, providing both the factual answer and supporting data.  The response is already optimal for this straightforward comparison question. If one wanted to enhance it further, the model could have added context about the relative sizes of these cities nationally (e.g., mentioning that Los Angeles is the second-most populous city in the US while Chicago is the third), or included population density information since the land area data was available. However, these additions weren't necessary to fully answer the specific question asked.
# 2             What is the population density of San Francisco?           10.0   calculation_based      Basic                                          The model's response correctly addresses the question about San Francisco's population density. It properly identifies the calculation method (population divided by land area), uses the correct data from the provided dataset (population of 815,201 and land area of 46.9 square miles), and performs the calculation accurately. The result of 17,381.7 people per square mile (rounded to 17,382) is mathematically correct.\n\nThe response also provides useful context by noting that this makes San Francisco one of the most densely populated cities in the United States, which adds valuable perspective to the raw number. The model properly handles the data formatting and presents the information in a clear, step-by-step manner that shows its reasoning process.  The model response deserves a perfect score because:\n1. It correctly identified the calculation needed (population density = population ÷ land area)\n2. It used the exact figures provided in the dataset (815,201 people and 46.9 square miles)\n3. It performed the mathematical calculation accurately (17,381.7 people per square mile)\n4. It rounded appropriately and presented the final answer clearly (approximately 17,382 people per square mile)\n5. It added relevant context about San Francisco's density ranking among US cities\n6. The response was well-structured, showing the formula first, then the data used, followed by the calculation and final answer                                                                                                                                                                                                      The response is comprehensive and accurate as is. If anything, it could potentially include comparisons to other major US cities' population densities to provide even more context, but this goes beyond the scope of the original question and the model handled the core task perfectly.
# 3            What is the land area of Houston in square miles?           10.0      factual_lookup      Basic                                                                                                                                                                                                                                                                                                                                                                                                                                                                  The model's response is accurate and directly answers the question. It correctly states that the land area of Houston, Texas is 670.2 square miles, which matches exactly with the information provided in the dataset context. The response is concise and to the point, providing exactly the information that was requested without unnecessary elaboration.                                                                                                                                         The model deserves a perfect score because:\n1. Data Accuracy: The land area figure (670.2 square miles) is exactly correct according to the dataset.\n2. The response properly attributes the information to the "provided context data."\n3. The response is appropriately concise for a straightforward factual lookup question.\n4. The model correctly identified the relevant data point from the dataset without adding unnecessary or potentially incorrect information.\n5. The formatting of the response is clear and professional.                                                                                                                                                                                           No improvements needed. For this type of straightforward factual lookup question, the concise and accurate response is ideal. If the question had asked for additional context (such as how Houston's land area compares to other major cities), then additional analysis would have been appropriate.
# 4    List the top 3 most populous cities in the United States.           10.0  ranking_comparison      Basic                                                                                                                                                                                                                                                            The model's response correctly identifies the top 3 most populous cities in the United States as New York City, Los Angeles, and Chicago. The population figures provided (NYC: 8,478,072; Los Angeles: 3,878,704; Chicago: 2,721,308) match exactly with the dataset context provided. The response is straightforward and directly answers the question without unnecessary elaboration. The model also appropriately notes that these figures represent the most recent census data available, which provides helpful context about the source of the information.  The model response deserves a perfect score because:\n1. Data Accuracy: All city names and population figures match exactly with the dataset.\n2. Ranking Correctness: The cities are correctly ordered by population size.\n3. Data Handling: The population numbers are properly formatted with commas.\n4. Completeness: The response fully answers the question by providing the top 3 cities as requested.\n5. Context: The model appropriately notes these are census figures, providing useful context about the data source.\n\nThe question was straightforward, requiring only ranking of cities by population and reporting the top 3, which the model executed perfectly.     The response is already comprehensive and accurate for this basic ranking question. If one wanted to enhance it further, the model could potentially include:\n- The state abbreviations for each city (NY, CA, IL)\n- The significant population differences between these cities (showing NYC is more than twice the size of Los Angeles)\n- The year of the census data being referenced\nHowever, these additions aren't necessary for a complete answer to the specific question asked.
# 5                 Calculate the population density of Chicago.           10.0   calculation_based      Basic      The model's response correctly calculates the population density of Chicago by dividing the population by the land area. The data used matches exactly what was provided in the dataset context:\n- Population: 2,721,308 people\n- Land area: 227.7 square miles\n\nThe calculation is mathematically correct:\n2,721,308 ÷ 227.7 = 11,951.7 (which the model rounds to 11,952 people per square mile)\n\nThe model presents the information in a clear, structured format with:\n1. A clear formula explanation\n2. Identification of the required data points\n3. Step-by-step calculation\n4. A final conclusion statement with the rounded result\n\nThe response is straightforward and directly answers the question without unnecessary elaboration, which is appropriate for this type of calculation-based query.                                     The model deserves a perfect score because:\n1. It used the correct data points from the provided dataset\n2. The mathematical calculation is accurate\n3. The methodology is clearly explained\n4. The response is well-structured with a formula, calculation steps, and conclusion\n5. The final answer is properly rounded and includes the appropriate unit of measurement (people per square mile)\n6. The response is appropriately concise for this straightforward calculation question\n\nThe model didn't need to provide additional context or comparisons since the question only asked for Chicago's population density calculation.                       The response is excellent as is for this straightforward calculation. If one wanted to enhance it, the model could have:\n1. Provided context about how Chicago's density compares to other major US cities\n2. Mentioned where Chicago ranks nationally in terms of population density\n3. Added a brief note about what population density indicates about urban development\n\nHowever, these would be supplementary details beyond the scope of the original question.
#
# ================================================================================
# CITIES EVALUATION ANALYSIS
# ================================================================================
#
# SCORE STATISTICS:
#   Average Score: 10.00/10
#   Median Score: 10.00/10
#   Score Range: 10.0 - 10.0
#
# QUESTION TYPE PERFORMANCE:
#   Calculation Based: 10.00 avg (2 questions)
#   Factual Lookup: 10.00 avg (2 questions)
#   Ranking Comparison: 10.00 avg (2 questions)
#
# COMPLEXITY PERFORMANCE:
#   Basic: 10.00 avg (6 questions)

# %% [markdown]
# ## **Performance Analysis**
#
# Based on our evaluation:
# - **Programmatic tests** reveal baseline accuracy challenges
# - **Contextual responses** show significant improvement with RAG
# - **Judge evaluations** provide nuanced quality assessment
#
# Next, let's see how this scales to production volumes...

# %%
# Configure scale test parameters
print(f"Scaling to {SCALE_TEST_SAMPLES:,} samples...")
print("\nThis simulation models:")
print("• Real-world performance degradation")
print("• Question type complexity variations")
print("• Judge evaluation variance")
print("• Production environment factors\n")
# Out:
# Scaling to 1,000 samples...
#
# This simulation models:
# • Real-world performance degradation
# • Question type complexity variations
# • Judge evaluation variance
# • Production environment factors

# %%
df, stats, _ = analyze_model_performance(n_samples=1000, random_seed=RANDOM_SEED, show_plots=False)
# Out:
# Overall Performance: 8.98 ± 1.07
# Outliers (< 6.84): 72 cases
# Outlier breakdown by question type:
# question_type
# ranking_comparison       38
# creative_writing         24
# factual_lookup            7
# technical_explanation     3
# dtype: int64
# Large-scale analysis complete! Model shows realistic performance distribution
# Mean degradation from perfect (10.0) to production reality (8.98)
# 92.2% of cases meet quality thresholds - ready for production deployment
# 72 cases (7.2%) require human review - typical for scale
# Statistical significance achieved: can detect ±1.1 point performance changes

# %%
display_plot_with_analysis("score_distribution", df, stats, """
## Production Performance Distribution Analysis
Our model is performing well, based on our threshold we can see that we have 72 outliers...
""")


display_plot_with_analysis("quality_distribution", df, stats, """
## Performance by Question Type Analysis
Different question types show varying performance levels...
""")
# Out:
# ## Production Performance Distribution Analysis
# Our model is performing well, based on our threshold we can see that we have 72 outliers...
# ## Performance by Question Type Analysis
# Different question types show varying performance levels...

# %% [markdown]
# **Overall System Health:** The model achieves a mean score of 8.98/10 with 68.1% excellent ratings, indicating strong baseline performance. However, 7.2% of cases (72 outliers) fall below the quality threshold of 6.84, signaling specific failure modes that need attention.

# %% [markdown]
# ### Outlier Analysis

# %%
display_plot_with_analysis("performance_by_type", df, stats, """
## Performance by Question Type Analysis
The outliers aren't randomly distributed—they cluster in specific task types. Ranking Comparison shows
38 outliers with notably lower average scores while Creative Writing has 24 outliers. 
""")

display_plot_with_analysis("outlier_analysis", df, stats, """
## Outlier Analysis
Examining outliers helps identify failure modes. The scatter plot visually confirms these tasks consistently underperform 
across different evaluation IDs.
""")
# Out:
# ## Performance by Question Type Analysis
# The outliers aren't randomly distributed—they cluster in specific task types. Ranking Comparison shows
# 38 outliers with notably lower average scores while Creative Writing has 24 outliers.
# ## Outlier Analysis
# Examining outliers helps identify failure modes. The scatter plot visually confirms these tasks consistently underperform
# across different evaluation IDs.

# %% [markdown]
# ## Variance Analysis

# %%
display_plot_with_analysis("variance_analysis", df, stats, """
Box plots reveal high variance in Ranking Comparison and Creative Writing tasks (wider boxes and longer whiskers),
indicating the model's unreliable performance on these question types. In contrast, Calculation-Based and Technical Explanation
tasks show tighter distributions, suggesting more predictable outputs.

""")
# Out:
# Box plots reveal high variance in Ranking Comparison and Creative Writing tasks (wider boxes and longer whiskers),
# indicating the model's unreliable performance on these question types. In contrast, Calculation-Based and Technical Explanation
# tasks show tighter distributions, suggesting more predictable outputs.

# %% [markdown]
# **Production Readiness:** With 92.2% meeting SLA expectations, the system is deployment-ready, but the 72 cases flagged for human review represent a manageable workload for quality assurance teams.

# %% [markdown]
# ---
#
# ## How can we improve our solution?
#
# **Targeted Prompt Engineering:**
# - **For Ranking Comparisons (38 outliers):** Implement structured evaluation frameworks with explicit criteria (e.g., "Compare based on: accuracy, completeness, relevance") to reduce ambiguity
# - **For Creative Writing (24 outliers):** Add few-shot examples demonstrating desired output quality and style consistency
#
# **Judge Model Refinement:**
# - Implement ensemble judging for high-variance task types (Ranking & Creative Writing) where multiple judge scores are averaged
# - Calibrate judge scoring rubrics specifically for subjective tasks to reduce score dispersion shown in Step 5
#
# **Tiered Quality Control System:**
# - **Auto-pass (scores ≥8.5):** Deploy directly to production
# - **Human-in-the-loop (scores 6.84-8.5):** Route to quick review queue
# - **Mandatory review (scores <6.84):** Deep investigation of the 72 flagged cases to identify root causes
#
# **Continuous Monitoring:**
# - Set up alerts when task-specific performance drops below historical baselines (using Step 2 benchmarks)
# - Weekly analysis of new outliers to catch emerging failure patterns early
# - A/B test prompt improvements on historically problematic question types, measuring impact on variance reduction (Step 5 metrics)
#
# **Data Quality Investigation:**
# - The remaining 18 scattered outliers (beyond Ranking and Creative Writing) suggest potential data quality issues—audit these cases for prompt ambiguity, incorrect ground truth, or edge cases that need handling
# ```

# %% [markdown]
# ---
# ## What We've Accomplished
#
# 1. **Built a comprehensive evaluation framework** combining programmatic and judge-based evaluation
# 2. **Demonstrated the power of context** through RAG implementation
# 3. **Scaled our evaluation** to production volumes
# 4. **Identified performance patterns** across question types

# %% [markdown]
# ## Key Takeaways
#
# - **Without context**: Models can struggle with factual accuracy (~33% success rate)
# - **With context (RAG)**: Performance improves dramatically (>90% success rate)
# - **At scale**: Performance remains stable with predictable variance
#
# ### Next Steps
#
# 1. **Expand question diversity** - Add more complex, multi-step questions
# 2. **Implement continuous monitoring** - Set up automated evaluation pipelines
# 3. **Optimize for weak areas** - Focus on improving lowest-performing categories
# 4. **A/B test improvements** - Compare different prompting strategies
#
# ### Final Thought
#
# > "The quality of an AI system is only as good as its evaluation framework. Today, you've built a robust foundation for continuous improvement."
#
# ---
